# %%
using Revise

# %%
using RigidBodyDynamics
using DrakeVisualizer
DrakeVisualizer.any_open_windows() || DrakeVisualizer.new_window()
using RigidBodyTreeInspector
using Gurobi
import StochasticOptimization
using Plots; gr()
using JLD2
using ProgressMeter
using Optim

# %%
import LCPSim
import LearningMPC
import Hoppers
import Nets
# Out:
# INFO: Recompiling stale cache file /home/rdeits/locomotion/explorations/learning-mpc/packages/lib/v0.6/LearningMPC.ji for module LearningMPC.
# INFO: Precompiling module Hoppers.

# %%
robot = Hoppers.Hopper()
mechanism = robot.mechanism
xstar = Hoppers.nominal_state(robot)

basevis = Visualizer()[:hopper]
setgeometry!(basevis, robot)
settransform!(basevis[:robot], xstar)

mpc_params = LearningMPC.MPCParams(
    Δt=0.05,
    horizon=10,
    mip_solver=GurobiSolver(Gurobi.Env(), OutputFlag=0, TimeLimit=120, MIPGap=1e-1, FeasibilityTol=1e-3),
    lcp_solver=GurobiSolver(Gurobi.Env(), OutputFlag=0))

Q, R = Hoppers.default_costs(robot)
foot = findbody(mechanism, "foot")
lqrsol = LearningMPC.LQRSolution(xstar, Q, R, mpc_params.Δt, [Point3D(default_frame(foot), 0., 0., 0.)])
lqrsol.S .= 1 ./ mpc_params.Δt .* Q

hidden_widths = [10, 10]
activation = Nets.elu
net = LearningMPC.control_net(mechanism, hidden_widths, activation)
for I in eachindex(net.params.data)
    net.params.data[I] += 0.1 * randn()
end

net_controller = x -> Nets.predict(net, state_vector(x))

mpc_controller = LearningMPC.MPCController(mechanism, 
    robot.environment, mpc_params, lqrsol, 
    [net_controller, lqrsol]);

sample_sink = LearningMPC.MPCSampleSink{Float64}()
playback_sink = LearningMPC.PlaybackSink(basevis[:robot], 0.25 * mpc_params.Δt)
live_viewer = LearningMPC.live_viewer(mechanism, basevis[:robot])

mpc_controller.callback = LearningMPC.call_each(
    sample_sink,
#     playback_sink,
#     (args...) -> println("tick")
#     (x, results) -> live_viewer(x)
)


dagger_controller = LearningMPC.call_each(
    LearningMPC.dagger_controller(
        mpc_controller,
        net_controller,
        0.5),
    live_viewer
    )

termination = x -> false

dataset = LearningMPC.Dataset(lqrsol)

gradient_sensitivity = 0.2

x0 = MechanismState{Float64}(mechanism)

x_init = MechanismState{Float64}(mechanism)
set_configuration!(x_init, [1.0, 1.0])
set_velocity!(x_init, [0., 0.])
# x_init = xstar

function collect_into!(data::Vector{<:LearningMPC.Sample}, σ_q=0.5, σ_v=1.0)
    empty!(sample_sink)
    LearningMPC.randomize!(x0, x_init, σ_q, σ_v)
    if configuration(x0)[1] - configuration(x0)[2] < 0
        set_configuration!(x0, [configuration(x0)[2], configuration(x0)[2]])
    end
    results = LCPSim.simulate(x0, 
        dagger_controller,
        robot.environment, mpc_params.Δt, 50, 
        mpc_params.lcp_solver;
        termination=termination);
    samples_to_keep = filter(1:length(sample_sink.samples)) do i
        for j in (i+1):length(sample_sink.samples)
            if norm(sample_sink.samples[j].state .- sample_sink.samples[i].state) < 1e-2
                return false
            end
        end
        return true
    end
    append!(data, sample_sink.samples[samples_to_keep])
#     append!(data, sample_sink.samples)
end

collect_into!(dataset.training_data, 0.0, 0.0)
f, g! = Nets.cost_function(LearningMPC.features, net, dataset.training_data, gradient_sensitivity)

all_losses(net, dataset) = (LearningMPC.training_loss(net, dataset),
                            LearningMPC.validation_loss(net, dataset),
                            f(net.params.data))
# Out:
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# all_losses (generic function with 1 method)

# %%
# LearningMPC.randomize!(x0, x_init, 0.0, 0.0)
# results = LCPSim.simulate(x0, 
#     mpc_controller,
#     robot.environment, mpc_params.Δt, 50, mpc_params.lcp_solver);

# %%
# LearningMPC.playback(basevis[:robot], results, mpc_params.Δt)

# %%
losses = Tuple{Float64, Float64, Float64}[]
snapshots = LearningMPC.Snapshot{Float64}[]
gr()

@showprogress for i in 1:10
    for i in 1:2
        collect_into!(dataset.training_data)
    end
    collect_into!(dataset.testing_data)
    collect_into!(dataset.validation_data);
    
    optim_results = Optim.optimize(f, g!, copy(net.params.data), LBFGS(), Optim.Options(allow_f_increases=true, iterations=100))
    @show optim_results
    net.params.data .= optim_results.minimizer
    push!(losses, all_losses(net, dataset))
    
    push!(snapshots, LearningMPC.Snapshot(net.params.data, net))
    
#     jldopen("hopper-$gradient_sensitivity.jld2", "w") do file
#         file["dataset"] = dataset
#         file["snapshots"] = snapshots
#     end
    
    plt = plot(first.(losses), label="training", yscale=:log10)
    plot!(plt, getindex.(losses, 2), label="validation")
    plot!(plt, getindex.(losses, 3), label="learning")
    ylims!(plt, (1, ylims(plt)[2]))
    display(plt)
end
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 50.9599,375.813 580.315,375.813 580.315,11.811 50.9599,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="50" y="11" width="530" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   183.299,375.813 183.299,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   315.637,375.813 315.637,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   447.976,375.813 447.976,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,304.445 580.315,304.445
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,233.077 580.315,233.077
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,161.709 580.315,161.709
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,90.3405 580.315,90.3405
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,18.9723 580.315,18.9723
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   183.299,375.813 183.299,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.637,375.813 315.637,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   447.976,375.813 447.976,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 58.9002,375.813
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,304.445 58.9002,304.445
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,233.077 58.9002,233.077
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,161.709 58.9002,161.709
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,90.3405 58.9002,90.3405
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,18.9723 58.9002,18.9723
#   "/>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 50.9599, 389.613)" x="50.9599" y="389.613">1.00</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 183.299, 389.613)" x="183.299" y="389.613">1.25</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.637, 389.613)" x="315.637" y="389.613">1.50</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 447.976, 389.613)" x="447.976" y="389.613">1.75</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">2.00</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 380.313)" x="44.9599" y="380.313">10^0.0</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 308.945)" x="44.9599" y="308.945">10^0.5</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 237.577)" x="44.9599" y="237.577">10^1.0</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 166.209)" x="44.9599" y="166.209">10^1.5</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 94.8405)" x="44.9599" y="94.8405">10^2.0</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 23.4723)" x="44.9599" y="23.4723">10^2.5</text>
# </g>
# <polygon clip-path="url(#clip4800)" points="
# 452.253,93.171 562.315,93.171 562.315,32.691 452.253,32.691
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   452.253,93.171 562.315,93.171 562.315,32.691 452.253,32.691 452.253,93.171
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   458.253,47.811 494.253,47.811
#   "/>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 500.253, 52.311)" x="500.253" y="52.311">training</text>
# </g>
# <polyline clip-path="url(#clip4800)" style="stroke:#e26f46; stroke-width:1;
# optim_results = Results of Optimization Algorithm
#  * Algorithm: L-BFGS
#  * Starting Point: [0.7768450991588259,-1.3795841460841682, ...]
#  * Minimizer: [0.6493515188499748,-1.3609865713609495, ...]
#  * Minimum: 3.549532e+02
#  * Iterations: 100
#  * Convergence: false
#    * |x - x'| < 1.0e-32: false
#      |x - x'| = 2.88e-05
#    * |f(x) - f(x')| / |f(x)| < 1.0e-32: false
#      |f(x) - f(x')| / |f(x)| = 1.00e-06
#    * |g(x)| < 1.0e-08: false
#      |g(x)| = 4.22e+01
#    * stopped by an increasing objective: true
#    * Reached Maximum Number of Iterations: true
#  * Objective Calls: 4757
#  * Gradient Calls: 4757
# Progress:  10%|████                                     |  ETA: 0:03:25
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5000)" points="
# 50.9599,375.813 580.315,375.813 580.315,11.811 50.9599,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="50" y="11" width="530" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   183.299,375.813 183.299,11.811
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   315.637,375.813 315.637,11.811
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   447.976,375.813 447.976,11.811
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,307.247 580.315,307.247
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,238.681 580.315,238.681
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,170.114 580.315,170.114
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,101.548 580.315,101.548
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,32.9816 580.315,32.9816
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,370.353
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   183.299,375.813 183.299,370.353
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.637,375.813 315.637,370.353
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   447.976,375.813 447.976,370.353
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 58.9002,375.813
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,307.247 58.9002,307.247
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,238.681 58.9002,238.681
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,170.114 58.9002,170.114
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,101.548 58.9002,101.548
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,32.9816 58.9002,32.9816
#   "/>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 50.9599, 389.613)" x="50.9599" y="389.613">1.00</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 183.299, 389.613)" x="183.299" y="389.613">1.25</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.637, 389.613)" x="315.637" y="389.613">1.50</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 447.976, 389.613)" x="447.976" y="389.613">1.75</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">2.00</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 380.313)" x="44.9599" y="380.313">10^0.0</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 311.747)" x="44.9599" y="311.747">10^0.5</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 243.181)" x="44.9599" y="243.181">10^1.0</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 174.614)" x="44.9599" y="174.614">10^1.5</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 106.048)" x="44.9599" y="106.048">10^2.0</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 37.4816)" x="44.9599" y="37.4816">10^2.5</text>
# </g>
# <polyline clip-path="url(#clip5002)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,39.7872 580.315,12.1961
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#e26f46; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,86.9157 580.315,22.3303
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#3da44d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,26.1015 580.315,11.811
#   "/>
# <polygon clip-path="url(#clip5000)" points="
# 452.253,93.171 562.315,93.171 562.315,32.691 452.253,32.691
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   452.253,93.171 562.315,93.171 562.315,32.691 452.253,32.691 452.253,93.171
#   "/>
# <polyline
# optim_results = Results of Optimization Algorithm
#  * Algorithm: L-BFGS
#  * Starting Point: [0.6493515188499748,-1.3609865713609495, ...]
#  * Minimizer: [0.7137108682068372,-1.291400238708888, ...]
#  * Minimum: 4.512115e+02
#  * Iterations: 100
#  * Convergence: false
#    * |x - x'| < 1.0e-32: false
#      |x - x'| = 3.16e-05
#    * |f(x) - f(x')| / |f(x)| < 1.0e-32: false
#      |f(x) - f(x')| / |f(x)| = 1.00e-06
#    * |g(x)| < 1.0e-08: false
#      |g(x)| = 1.55e+01
#    * stopped by an increasing objective: true
#    * Reached Maximum Number of Iterations: true
#  * Objective Calls: 4816
#  * Gradient Calls: 4816
# Progress:  20%|████████                                 |  ETA: 0:02:45
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5200)" points="
# 50.9599,375.813 580.315,375.813 580.315,11.811 50.9599,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="50" y="11" width="530" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   183.299,375.813 183.299,11.811
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   315.637,375.813 315.637,11.811
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   447.976,375.813 447.976,11.811
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,310.519 580.315,310.519
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,245.225 580.315,245.225
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,179.93 580.315,179.93
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,114.636 580.315,114.636
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,49.3415 580.315,49.3415
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   183.299,375.813 183.299,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.637,375.813 315.637,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   447.976,375.813 447.976,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 58.9002,375.813
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,310.519 58.9002,310.519
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,245.225 58.9002,245.225
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,179.93 58.9002,179.93
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,114.636 58.9002,114.636
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,49.3415 58.9002,49.3415
#   "/>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 50.9599, 389.613)" x="50.9599" y="389.613">1.0</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 183.299, 389.613)" x="183.299" y="389.613">1.5</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.637, 389.613)" x="315.637" y="389.613">2.0</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 447.976, 389.613)" x="447.976" y="389.613">2.5</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3.0</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 380.313)" x="44.9599" y="380.313">10^0.0</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 315.019)" x="44.9599" y="315.019">10^0.5</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 249.725)" x="44.9599" y="249.725">10^1.0</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 184.43)" x="44.9599" y="184.43">10^1.5</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 119.136)" x="44.9599" y="119.136">10^2.0</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 53.8415)" x="44.9599" y="53.8415">10^2.5</text>
# </g>
# <polyline clip-path="url(#clip5202)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,55.8224 315.637,29.5479 580.315,20.4496
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#e26f46; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,100.702 315.637,39.1985 580.315,25.292
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#3da44d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,42.7897 315.637,29.1812 580.315,11.811
#   "/>
# <polygon clip-path="url(#clip5200)" points="
# 452.253,93.171 562.315,93.171 562.315,32.691 452.253,32.691
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   452.253,93.171 562.315,93.171 562.315,32.691 452.253,32.
# optim_results = Results of Optimization Algorithm
#  * Algorithm: L-BFGS
#  * Starting Point: [0.7137108682068372,-1.291400238708888, ...]
#  * Minimizer: [0.679775628482949,-1.275136742741146, ...]
#  * Minimum: 6.129064e+02
#  * Iterations: 100
#  * Convergence: false
#    * |x - x'| < 1.0e-32: false
#      |x - x'| = 1.05e-05
#    * |f(x) - f(x')| / |f(x)| < 1.0e-32: false
#      |f(x) - f(x')| / |f(x)| = 1.00e-06
#    * |g(x)| < 1.0e-08: false
#      |g(x)| = 1.10e+01
#    * stopped by an increasing objective: true
#    * Reached Maximum Number of Iterations: true
#  * Objective Calls: 4444
#  * Gradient Calls: 4444
# Progress:  30%|████████████                             |  ETA: 0:02:24
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5400)" points="
# 50.9599,375.813 580.315,375.813 580.315,11.811 50.9599,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="50" y="11" width="530" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   227.412,375.813 227.412,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.863,375.813 403.863,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,310.658 580.315,310.658
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,245.502 580.315,245.502
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,180.346 580.315,180.346
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,115.191 580.315,115.191
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,50.035 580.315,50.035
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,370.353
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   227.412,375.813 227.412,370.353
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.863,375.813 403.863,370.353
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 58.9002,375.813
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,310.658 58.9002,310.658
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,245.502 58.9002,245.502
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,180.346 58.9002,180.346
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,115.191 58.9002,115.191
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,50.035 58.9002,50.035
#   "/>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 50.9599, 389.613)" x="50.9599" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 227.412, 389.613)" x="227.412" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.863, 389.613)" x="403.863" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 380.313)" x="44.9599" y="380.313">10^0.0</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 315.158)" x="44.9599" y="315.158">10^0.5</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 250.002)" x="44.9599" y="250.002">10^1.0</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 184.846)" x="44.9599" y="184.846">10^1.5</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 119.691)" x="44.9599" y="119.691">10^2.0</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 54.535)" x="44.9599" y="54.535">10^2.5</text>
# </g>
# <polyline clip-path="url(#clip5402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,56.5021 227.412,30.2834 403.863,21.2045 580.315,19.1129
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#e26f46; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,101.286 227.412,39.9135 403.863,26.0366 580.315,21.613
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#3da44d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,43.4971 227.412,29.9175 403.863,12.5843 580.315,11.811
#   "/>
# <polygon clip-path="url(#clip5400)" points="
# 452.253,93.171 562.315,93.171 562.315,32.691 452.253,32.691
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   452.253,93.171 562.315,93.171 562.315,32.691 452.253,32.691 452.253,93.171
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   458.253,47.811 494.253,47.811
#   "/>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 500.253, 52.311)" x="500.253" y="52.311">training</text>
# </g>
# <polyline clip-path="url(#clip5400)" style="stroke:#e26f46; stroke-width:1; stroke-opacity:1
# optim_results = Results of Optimization Algorithm
#  * Algorithm: L-BFGS
#  * Starting Point: [0.679775628482949,-1.275136742741146, ...]
#  * Minimizer: [0.6782216525985143,-1.0879369560534558, ...]
#  * Minimum: 6.213380e+02
#  * Iterations: 100
#  * Convergence: false
#    * |x - x'| < 1.0e-32: false
#      |x - x'| = 1.42e-05
#    * |f(x) - f(x')| / |f(x)| < 1.0e-32: false
#      |f(x) - f(x')| / |f(x)| = 1.00e-06
#    * |g(x)| < 1.0e-08: false
#      |g(x)| = 2.09e+01
#    * stopped by an increasing objective: true
#    * Reached Maximum Number of Iterations: true
#  * Objective Calls: 4847
#  * Gradient Calls: 4847
# Progress:  40%|████████████████                         |  ETA: 0:02:09
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5600)" points="
# 50.9599,375.813 580.315,375.813 580.315,11.811 50.9599,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="50" y="11" width="530" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   183.299,375.813 183.299,11.811
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   315.637,375.813 315.637,11.811
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   447.976,375.813 447.976,11.811
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,311.722 580.315,311.722
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,247.631 580.315,247.631
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,183.54 580.315,183.54
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,119.449 580.315,119.449
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,55.3573 580.315,55.3573
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   183.299,375.813 183.299,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.637,375.813 315.637,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   447.976,375.813 447.976,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 58.9002,375.813
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,311.722 58.9002,311.722
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,247.631 58.9002,247.631
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,183.54 58.9002,183.54
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,119.449 58.9002,119.449
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,55.3573 58.9002,55.3573
#   "/>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 50.9599, 389.613)" x="50.9599" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 183.299, 389.613)" x="183.299" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.637, 389.613)" x="315.637" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 447.976, 389.613)" x="447.976" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 380.313)" x="44.9599" y="380.313">10^0.0</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 316.222)" x="44.9599" y="316.222">10^0.5</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 252.131)" x="44.9599" y="252.131">10^1.0</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 188.04)" x="44.9599" y="188.04">10^1.5</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 123.949)" x="44.9599" y="123.949">10^2.0</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 59.8573)" x="44.9599" y="59.8573">10^2.5</text>
# </g>
# <polyline clip-path="url(#clip5602)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,61.7188 183.299,35.9285 315.637,26.9978 447.976,24.9404 580.315,27.8842
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#e26f46; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,105.771 183.299,45.4012 315.637,31.751 447.976,27.3997 580.315,31.596
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#3da44d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,48.9263 183.299,35.5685 315.637,18.5184 447.976,17.7578 580.315,11.811
#   "/>
# <polygon clip-path="url(#clip5600)" points="
# 452.253,93.171 562.315,93.171 562.315,32.691 452.253,32.691
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opac
# optim_results = Results of Optimization Algorithm
#  * Algorithm: L-BFGS
#  * Starting Point: [0.6782216525985143,-1.0879369560534558, ...]
#  * Minimizer: [0.6112627898485008,-0.5947013845318682, ...]
#  * Minimum: 6.913870e+02
#  * Iterations: 100
#  * Convergence: false
#    * |x - x'| < 1.0e-32: false
#      |x - x'| = 1.71e-05
#    * |f(x) - f(x')| / |f(x)| < 1.0e-32: false
#      |f(x) - f(x')| / |f(x)| = 1.00e-06
#    * |g(x)| < 1.0e-08: false
#      |g(x)| = 1.26e+01
#    * stopped by an increasing objective: true
#    * Reached Maximum Number of Iterations: true
#  * Objective Calls: 4502
#  * Gradient Calls: 4502
# Progress:  50%|████████████████████                     |  ETA: 0:01:49
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5800)" points="
# 50.9599,375.813 580.315,375.813 580.315,11.811 50.9599,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="50" y="11" width="530" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   156.831,375.813 156.831,11.811
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   262.702,375.813 262.702,11.811
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   368.573,375.813 368.573,11.811
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   474.444,375.813 474.444,11.811
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,312.343 580.315,312.343
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,248.872 580.315,248.872
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,185.401 580.315,185.401
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,121.93 580.315,121.93
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,58.459 580.315,58.459
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   156.831,375.813 156.831,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   262.702,375.813 262.702,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   368.573,375.813 368.573,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   474.444,375.813 474.444,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 58.9002,375.813
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,312.343 58.9002,312.343
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,248.872 58.9002,248.872
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,185.401 58.9002,185.401
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
# ...
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.186, 389.613)" x="139.186" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 227.412, 389.613)" x="227.412" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.637, 389.613)" x="315.637" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.863, 389.613)" x="403.863" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 492.089, 389.613)" x="492.089" y="389.613">6</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">7</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 380.313)" x="44.9599" y="380.313">10^0.0</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 316.843)" x="44.9599" y="316.843">10^0.5</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 253.372)" x="44.9599" y="253.372">10^1.0</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 189.901)" x="44.9599" y="189.901">10^1.5</text>
# </g>
# <g clip-path="url(#clip6000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 126.43)" x="44.9599" y="12
# optim_results = Results of Optimization Algorithm
#  * Algorithm: L-BFGS
#  * Starting Point: [0.610890127176916,-0.5946984441467545, ...]
#  * Minimizer: [0.6103886612738743,-0.5947060551264451, ...]
#  * Minimum: 7.249321e+02
#  * Iterations: 100
#  * Convergence: false
#    * |x - x'| < 1.0e-32: false
#      |x - x'| = 4.10e-06
#    * |f(x) - f(x')| / |f(x)| < 1.0e-32: false
#      |f(x) - f(x')| / |f(x)| = 1.00e-06
#    * |g(x)| < 1.0e-08: false
#      |g(x)| = 4.08e+00
#    * stopped by an increasing objective: true
#    * Reached Maximum Number of Iterations: true
#  * Objective Calls: 5001
#  * Gradient Calls: 5001
# Progress:  70%|█████████████████████████████            |  ETA: 0:01:13
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6200)" points="
# 50.9599,375.813 580.315,375.813 580.315,11.811 50.9599,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="50" y="11" width="530" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   126.582,375.813 126.582,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   202.204,375.813 202.204,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   277.826,375.813 277.826,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   353.448,375.813 353.448,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   429.071,375.813 429.071,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   504.693,375.813 504.693,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,312.343 580.315,312.343
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,248.872 580.315,248.872
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,185.401 580.315,185.401
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,121.93 580.315,121.93
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9599,58.459 580.315,58.459
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,11.811
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 50.9599,370.353
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   126.582,375.813 126.582,370.353
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   202.204,375.813 202.204,370.353
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   277.826,375.813 277.826,370.353
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   353.448,375.813 353.448,370.353
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   429.071,375.813 429.071,370.353
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   504.693,375.813 504.693,370.353
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,375.813 58.9002,375.813
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,312.343 58.9002,312.343
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,248.872 58.9002,248.872
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,185.401 58.9002,185.401
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,121.93 58.9002,121.93
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9599,58.459 58.9002,58.459
#   "/>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 50.9599, 389.613)" x="50.9599" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 126.582, 389.613)" x="126.582" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 202.204, 389.613)" x="202.204" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 277.826, 389.613)" x="277.826" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 353.448, 389.613)" x="353.448" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 429.071, 389.613)" x="429.071" y="389.613">6</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 504.693, 389.613)" x="504.693" y="389.613">7</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">8</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 380.313)" x="44.9599" y="380.313">10^0.0</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.9599, 316.843)" x="44.9599" y="316.843">10^0.5</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-an
# optim_results = Results of Optimization Algorithm
#  * Algorithm: L-BFGS
#  * Starting Point: [0.6103886612738743,-0.5947060551264451, ...]
#  * Minimizer: [0.6097456785595025,-0.5947542610664387, ...]
#  * Minimum: 7.251126e+02
#  * Iterations: 100
#  * Convergence: false
#    * |x - x'| < 1.0e-32: false
#      |x - x'| = 3.36e-06
#    * |f(x) - f(x')| / |f(x)| < 1.0e-32: false
#      |f(x) - f(x')| / |f(x)| = 1.00e-06
#    * |g(x)| < 1.0e-08: false
#      |g(x)| = 2.32e+00
#    * stopped by an increasing objective: true
#    * Reached Maximum Number of Iterations: true
#  * Objective Calls: 5125
#  * Gradient Calls: 5125
# Progress:  80%|█████████████████████████████████        |  ETA: 0:00:50
# captured: InterruptException()
# UndefVarError: mip_results not defined
#
# Stacktrace:
#  [1] run_mpc(::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Prismatic{Float64}},1}},2}}, ::LCPSim.Environment{Float64}, ::LearningMPC.MPCParams{Gurobi.GurobiSolver,Gurobi.GurobiSolver}, ::LearningMPC.LQRSolution{Float64}, ::Array{Function,1}) at /home/rdeits/locomotion/explorations/learning-mpc/modules/LearningMPC/src/mpc.jl:178
#  [2] (::LearningMPC.MPCController{Float64,LearningMPC.MPCParams{Gurobi.GurobiSolver,Gurobi.GurobiSolver},RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Prismatic{Float64}},1}},2}}})(::LCPSim.StateRecord{Float64,Float64}) at /home/rdeits/locomotion/explorations/learning-mpc/modules/LearningMPC/src/mpc.jl:247
#  [3] (::LearningMPC.##41#42{LearningMPC.MPCController{Float64,LearningMPC.MPCParams{Gurobi.GurobiSolver,Gurobi.GurobiSolver},RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Prismatic{Float64}},1}},2}}},##91#92,Float64})(::LCPSim.StateRecord{Float64,Float64}) at /home/rdeits/locomotion/explorations/learning-mpc/modules/LearningMPC/src/learning.jl:100
#  [4] #31 at /home/rdeits/locomotion/explorations/learning-mpc/modules/LearningMPC/src/learning.jl:62 [inlined]
#  [5] #simulate#17(::##93#94, ::Bool, ::Function, ::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Prismatic{Float64}},1}},2}}, ::LearningMPC.##31#33{LearningMPC.##41#42{LearningMPC.MPCController{Float64,LearningMPC.MPCParams{Gurobi.GurobiSolver,Gurobi.GurobiSolver},RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Prismatic{Float64}},1}},2}}},##91#92,Float64},Tuple{LearningMPC.##35#36{DrakeVisualizer.Visualizer,RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Prismatic{Float64}},1}},2}}}}}, ::LCPSim.Environment{Float64}, ::Float64, ::Int64, ::Gurobi.GurobiSolver) at /home/rdeits/locomotion/explorations/learning-mpc/submodules/LCPSim/src/simulation.jl:145
#  [6] (::LCPSim.#kw##simulate)(::Array{Any,1}, ::LCPSim.#simulate, ::RigidBodyDynamics.MechanismState{Float64,Float64,Float64,TypeSortedCollections.TypeSortedCollection{Tuple{Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Fixed{Float64}},1},Array{RigidBodyDynamics.Joint{Float64,RigidBodyDynamics.Prismatic{Float64}},1}},2}}, ::Function, ::LCPSim.Environment{Float64}, ::Float64, ::Int64, ::Gurobi.GurobiSolver) at ./<missing>:0
#  [7] collect_into!(::Array{LearningMPC.Sample{Float64},1}, ::Float64, ::Float64) at ./In[39]:72
#  [8] collect_into!(::Array{LearningMPC.Sample{Float64},1}) at ./In[39]:67
#  [9] macro expansion at ./In[42]:7 [inlined]
#  [10] macro expansion at /home/rdeits/locomotion/explorations/learning-mpc/packages/v0.6/ProgressMeter/src/ProgressMeter.jl:475 [inlined]
#  [11] anonymous at ./<missing>:?
#  [12] include_string(::String, ::String) at ./loading.jl:522

# %%
# @showprogress for i in 1:100
#     Nets.update!(net.params.data, optimizer, LearningMPC.features.(dataset.training_data))
#     optimizer.opts.learning_rate *= (1 - 3e-2)
#     push!(losses, all_losses(net, dataset))
# end

# %%
LearningMPC.randomize!(x0, x_init, 0.1, 0.5)
results = LCPSim.simulate(x0, 
    net_controller,
    robot.environment, mpc_params.Δt, 200, mpc_params.lcp_solver);

# %%
LearningMPC.playback(basevis[:robot], results, mpc_params.Δt)

# %%
plotly()
# Out:
# Plots.PlotlyBackend()

# %%
function slice(data)
    filter(data) do sample
        x = sample.state
        (abs(x[1] - x[2]) < 1e-1) && (abs(x[3] - x[4]) < 1e-1)
    end
end
# Out:
# slice (generic function with 1 method)

# %%
plt = plot([s.state[1] for s in slice(dataset.training_data)], [s.state[3] for s in slice(dataset.training_data)],
     [s.uJ[2, 1] for s in slice(dataset.training_data)], line=nothing, marker=:dot, markersize=0.3)
surface!(plt, linspace(0, 2), linspace(-4, 4), (x, y) -> net([x, x, y, y])[2])
# plot!(plt, [s.state[1] for s in dataset.training_data], [s.state[3] for s in dataset.training_data],
#      [net(s.state)[2] for s in dataset.training_data], line=nothing, marker=:dot, markersize=0.3, markercolor=:red)
zlims!(plt, -10, 50)
plt
# Out:
# <script src="file:///home/rdeits/locomotion/explorations/learning-mpc/packages/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="49995736-363a-4f32-b01e-b7abd19f4880" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('49995736-363a-4f32-b01e-b7abd19f4880');
#     Plotly.plot(PLOT, [{"xaxis":"x","colorbar":{"title":""},"yaxis":"y","x":[0.9999999999999998,0.887656702234805,0.9000622506630589,0.7213334896136934,0.9999996104444181,0.7110583339089291,0.7327820403936803,0.9999998741218484,0.7063878516507808,0.6665783887380858,0.7022439258253905,0.8133844442511414,0.8722745300662136,0.7468695987399331,0.9999998219493514,0.6960564077261241,0.7218959384840827,0.2499999999999995,0.24999999999999914,0.32547499999999874,0.7604424529987781,0.6976837929640303,0.6955762425014549,0.6501295919487632,0.6243846939615726,0.6741147959743816,0.41464399442911976,0.33129467992479,0.32342036542046027,0.5331637426388539,0.3048743649043849,0.24999999999999853,0.28784843438669494,0.2499999999999982,0.682611565671292,0.6980038175451029,0.6602903631588274,0.6390650445415357,0.6160862834061528,0.71649059935585,0.8205077817287049,0.45411488721913107,0.2529631173779348,0.2499999999999983,0.3254749999999982,0.5175130691076402,0.24999999999999956,0.2970388922887434,0.5896420865189027,0.5221648312613234,0.469010384758618,0.4943804066017015,0.5691907077724131,0.7194760089431249,0.9452363101138369,0.8476028883118977,0.7271323106495186,0.6821367329871391,0.719619289076343,0.24999999999999856,0.6276558982381358,0.5439406195325369,0.5357003408269385,0.6029350621213404,0.5274937933900028,0.338765047755561,0.3327419899634646,0.4021939321713687,0.7158466669893884,0.2499999999999986,0.2526648224912774,0.2661674526769709,0.2548355655124893,0.31897867834800775,0.99999951420787,0.6912656591511747,0.718702062651497,0.821613448313166,0.9999998173723185,0.6171534389834268,0.5295593214982741,0.4838770572046133,0.5023270661595323,0.5927430441063551,0.75863399791658,0.9999994689948626,0.4192644126572263,0.24999999999999858,0.2499999999999995,0.3254749999999994,0.8054675841625862,0.3955320787475391,0.24999999999999828,0.26077315922323496,0.39800979245378754,0.467091606694314,0.44172374082450605,0.431905819697844,0.5048353319804504,0.5944152213203004,0.5398438182932782,0.5319030033756137,0.5994371884579495,0.66058743556618,0.33115875846132037,0.2499999999999984,0.40033681402927157,0.6386103797938054,0.6054250000611281,0.24999999999999822,0.2499999999999984,0.3233094998326636,0.47209399966532894,0.6627030140980198,0.6655613151693456,0.4026479437857204,0.34793475608978264,0.3686965683938452,0.5572931140549401,0.5037940406950668,0.4154144049702325,0.3806686757971199,0.42985409656518464,0.6182394654478695,0.7972714682097721,0.7431277134190987,0.6941332529552913,0.640778243647114,0.5711361670751618,0.5353684170741814,0.5138692599470589,0.4081193778503436,0.41665866400522855,0.2727786908141633,0.2791452519015858,0.41611460250570054,0.5467173920223928,0.6720893735846322,0.5962546036705302,0.5483011631490365,0.5480133723617776,0.623200581574519,0.7738627681735395,0.99999950249816,0.24999999999999908,0.33602587034284376,0.3606514371806243,0.3390149539851371,0.29976616092634567,0.33285155608623135,0.4414119512461173,0.5363614302815638,0.345195622750918,0.3238653394270197,0.41331212643733645,0.4745651602174794,0.9999995759578661,0.5743723110008029,0.4219337721045187,0.4318100016446726,0.575177083319873,0.6413097222132484,0.7829173393983601],"showlegend":true,"mode":"lines+markers","name":"y1","z":[-1.9041307164327033,-0.15022221739994235,-3.209252075022544,40.0,-4.74414190012521,40.0,40.0,-4.557715584011741,39.9999999999999,39.999999999999794,40.0,40.00001492925435,10.73822556821731,40.000012656518884,-4.725409172547368,39.999999999999844,40.0,40.00000000001798,39.999999999999964,40.0,14.58093611988848,27.712998680457115,31.08625350129196,18.61449240570268,39.99999999999982,40.0,39.99999999999999,39.99999999999999,40.0,40.0,40.0,40.0,40.0,39.99999999999994,39.799090255348624,14.838460584836676,39.999999999999815,21.185864905523665,39.999999999999346,40.0,40.00001435938839,40.0,38.85526628226238,39.99999999999995,40.0,40.0,40.0,40.0,40.0,39.29941897689938,36.56333755841293,40.00000000000001,40.0,40.0,-7.0220853814246365,21.85707623904491,39.9999999 ...
