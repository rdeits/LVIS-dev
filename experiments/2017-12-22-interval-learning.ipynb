# %%
using Plots; gr()
using JLD2, FileIO
using Optim
using ReverseDiff
using ReverseDiff: @forward

# %%
import Nets
import LearningMPC
# Out:
# INFO: Recompiling stale cache file /home/rdeits/locomotion/explorations/learning-mpc/packages/lib/v0.6/LearningMPC.ji for module LearningMPC.

# %%
function interval_hinge_loss(x::T) where T
    if x < -1
        -1 - x
    elseif x > 1
        x - 1
    else
        zero(T)
    end
end

sample_loss = (net, sample) -> begin
    x, y = sample
    ŷ = Nets.predict(net, x)
    sum(@forward(interval_hinge_loss).((ŷ .- mean.(y)) ./ ((last.(y) .- first.(y)) ./ 2)))
end

function cost_function(sample_loss::Function, net::Nets.Net, training_data)
    function f(params)
        n = similar(net, params)
        mean(training_data) do sample
            sample_loss(n, sample)
        end
    end
    
    loss_tape = ReverseDiff.compile(ReverseDiff.GradientTape(f, (net.params.data,)))
    g! = (∇, params) -> ReverseDiff.gradient!((∇,), loss_tape, (params,))
    f, g!
end
# Out:
# cost_function (generic function with 1 method)

# %%
samples = load("2017-12-20-hopper-grid/grid_search.jld2")["samples"];

filter!(samples) do sample
    (sample.state[1] == 0.25 &&
     sample.state[2] == 0.25 &&
     sample.state[3] == sample.state[4])
end

# samples = samples[1:100:length(samples)]

x = [[s.state[3]] for s in samples]
y = [[(s.mip.objective_bound, s.mip.objective_value)] for s in samples];
training_data = collect(zip(x, y));

# %%
# training_data = [([0.0], [(1.0, 2.0)])]

# %%
net = Nets.Net(zeros(Nets.Params{Float64}, [1, 10, 10, 1]), Nets.elu)
for I in eachindex(net.params.data)
    net.params.data[I] += 0.1 * randn()
end

f, g! = cost_function(sample_loss, net, training_data)
# Out:
# (f, #578)

# %%
plt = scatter(first.(first.(training_data)), first.(first.(last.(training_data))))
scatter!(plt, first.(first.(training_data)), last.(first.(last.(training_data))), markercolor=colorant"red")
xs = linspace(-5, 5, 100)
plot!(plt, xs, first.(net.([[xi] for xi in xs])))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2400)" points="
# 35.5169,375.813 580.315,375.813 580.315,11.811 35.5169,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="11" width="546" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   102.332,370.353 102.332,17.2711
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   205.124,370.353 205.124,17.2711
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   307.916,370.353 307.916,17.2711
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   410.708,370.353 410.708,17.2711
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   513.5,370.353 513.5,17.2711
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,365.496 572.143,365.496
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,291.597 572.143,291.597
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,217.698 572.143,217.698
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,143.798 572.143,143.798
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,69.8991 572.143,69.8991
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,375.813 35.5169,11.811
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   102.332,375.813 102.332,370.353
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   205.124,375.813 205.124,370.353
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   307.916,375.813 307.916,370.353
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   410.708,375.813 410.708,370.353
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   513.5,375.813 513.5,370.353
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,365.496 43.6889,365.496
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,291.597 43.6889,291.597
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,217.698 43.6889,217.698
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,143.798 43.6889,143.798
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,69.8991 43.6889,69.8991
#   "/>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 102.332, 389.613)" x="102.332" y="389.613">-4</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 205.124, 389.613)" x="205.124" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 307.916, 389.613)" x="307.916" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 410.708, 389.613)" x="410.708" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 513.5, 389.613)" x="513.5" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 369.996)" x="29.5169" y="369.996">0</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 296.097)" x="29.5169" y="296.097">50</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 222.198)" x="29.5169" y="222.198">100</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 148.298)" x="29.5169" y="148.298">150</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 74.3991)" x="29.5169" y="74.3991">200</text>
# </g>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="50.9357" cy="54.3755" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="50.9357" cy="54.3755" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="61.2149" cy="61.2609" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="61.2149" cy="61.2609" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="71.4941" cy="67.7402" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="71.4941" cy="67.7402" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="81.7734" cy="73.8133" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="81.7734" cy="73.8133" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="92.0526" cy="69.7194" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="92.0526" cy="69.7194" r="3"/>
# <circle clip-path="url(#clip2402)" style="fill:#000000; stroke:none; fill-opacity:1" cx="102.332" cy="74.9802" r="4"/>
# <circle clip-path="url(#clip2402)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="102.332" cy="7

# %%
solver = LBFGS()
options = Optim.Options(allow_f_increases=false)
results = optimize(f, g!, copy(net.params.data), solver, options)
@show results
net.params.data .= results.minimizer;
# Out:
# results = Results of Optimization Algorithm
#  * Algorithm: L-BFGS
#  * Starting Point: [-0.01937387598201116,0.07915712857896127, ...]
#  * Minimizer: [-1.3007787589894435,2.4727211412770465, ...]
#  * Minimum: 9.420851e-02
#  * Iterations: 243
#  * Convergence: false
#    * |x - x'| < 1.0e-32: false
#      |x - x'| = 1.44e-04
#    * |f(x) - f(x')| / |f(x)| < 1.0e-32: false
#      |f(x) - f(x')| / |f(x)| = 6.95e-05
#    * |g(x)| < 1.0e-08: false
#      |g(x)| = 6.79e+00
#    * stopped by an increasing objective: false
#    * Reached Maximum Number of Iterations: false
#  * Objective Calls: 1750
#  * Gradient Calls: 1750
# WARNING: Linesearch failed, using alpha = 5.539234667799105e-5 and exiting optimization.

# %%
plt = scatter(first.(first.(training_data)), first.(first.(last.(training_data))))
scatter!(plt, first.(first.(training_data)), last.(first.(last.(training_data))), markercolor=colorant"red")
xs = linspace(-5, 5, 100)
plot!(plt, xs, first.(net.([[xi] for xi in xs])))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip