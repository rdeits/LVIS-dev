# %%
using RigidBodyDynamics
using RigidBodyDynamics.Contact
using QPControl
using LCPSim
using MeshCat
using MeshCatMechanisms
using LearningMPC
using LearningMPC.Models
using RigidBodySim
using Gurobi
using SimpleQP
using AtlasRobot
using StaticArrays
using Rotations
using IKMimic
# Out:
# HTML{String}("    <script class='js-collapse-script'>\n        var curMatch =\n            window.location.href\n            .match(/(.*?)\\/notebooks\\/.*\\.ipynb/);\n\n        curMatch = curMatch ||\n            window.location.href\n            .match(/(.*?)\\/apps\\/.*\\.ipynb/);\n\n        if ( curMatch ) {\n            \$('head').append('<base href=\"' + curMatch[1] + '/\">');\n        }\n    </script>\n")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/9db0e137604e898c25f194d972715156bd46cb81-assets/webio/dist/bundle.js'></script>")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/9db0e137604e898c25f194d972715156bd46cb81-assets/providers/ijulia_setup.js'></script>")
# HTML{String}("  <script class='js-collapse-script'>\n    \$('.js-collapse-script').parent('.output_subarea').css('padding', '0');\n  </script>\n")
# INFO: Loading HttpServer methods...
# INFO: Recompiling stale cache file /home/rdeits/locomotion/explorations/learning-mpc-2/packages/lib/v0.6/LearningMPC.ji for module LearningMPC.
# WARNING: using QPControl.MPCController in module LearningMPC conflicts with an existing identifier.

# %%
vis = Visualizer()
open(vis)
# Out:
# Listening on 0.0.0.0:8716...
# INFO: Serving MeshCat visualizer at http://127.0.0.1:8716

# %%
Δt = 0.002
# Out:
# 0.002

# %%
# state initialization
function init_atlas!(state::MechanismState)
    mechanism = state.mechanism
    zero!(state)
    kneebend = 1.1
    hipbendextra = 0.1
    for sideprefix in ('l', 'r')
        knee = findjoint(mechanism, "$(sideprefix)_leg_kny")
        hippitch = findjoint(mechanism, "$(sideprefix)_leg_hpy")
        anklepitch = findjoint(mechanism, "$(sideprefix)_leg_aky")
        set_configuration!(state, knee, [kneebend])
        set_configuration!(state, hippitch, [-kneebend / 2 + hipbendextra])
        set_configuration!(state, anklepitch, [-kneebend / 2 - hipbendextra])
        set_configuration!(state, findjoint(mechanism, "$(sideprefix)_arm_shx"), 
            sideprefix=='r' ? π/4 : -π/4)
    end
    floatingjoint = first(out_joints(root_body(mechanism), mechanism))
    set_configuration!(state, floatingjoint, [0, 0.85, 0])
    state
end
# Out:
# init_atlas! (generic function with 1 method)

# %%
reduced_model = BoxAtlas(add_contacts=true)
position_bounds(findjoint(mechanism(reduced_model), "floating_base")) .= RigidBodyDynamics.Bounds(-Inf, Inf)
delete!(vis)
mvis_reduced = MechanismVisualizer(reduced_model, vis[:reduced])
copy!(mvis_reduced, nominal_state(reduced_model))
for bodyname in [
        "r_hand_mount",
        "l_hand_mount",
        "r_foot_sole",
        "l_foot_sole",
        "pelvis"
    ]
    setelement!(mvis_reduced, default_frame(findbody(mechanism(reduced_model), bodyname)))
end


full_model = AtlasRobot.mechanism()
for jointname in ["back_bkx", "back_bky", "back_bkz"]
    joint = findjoint(full_model, jointname)
    replace_joint!(full_model, joint, 
        Joint(jointname, frame_before(joint), frame_after(joint), Fixed{Float64}())
    )
end

joint = findjoint(full_model, "pelvis_to_world")
replace_joint!(full_model, joint,
    Joint("pelvis_to_world", frame_before(joint), frame_after(joint),
    Planar{Float64}(SVector(0., 1, 0), SVector(0., 0, 1)))
)
effort_bounds(findjoint(full_model, "pelvis_to_world")) .= RigidBodyDynamics.Bounds(0, 0)

remove_fixed_tree_joints!(full_model)
add_environment_primitive!(full_model, 
    HalfSpace3D(
        Point3D(root_frame(full_model), 0., 0, 0), 
        FreeVector3D(root_frame(full_model), 0., 0, 1)))

for (name, offset, orientation) in [
        ("r_foot_sole", (0.0426, 0.0, -0.07645), RotX(0.0)), 
        ("l_foot_sole", (0.0426, 0.0, -0.07645), RotX(0.0)),
        ("r_hand_mount", (0.0, -0.1, 0.0), RotZYX(0., 0., π/2)),
        ("l_hand_mount", (0.0, -0.1, 0.0), RotZYX(0., π, π/2))
    ]
    frame = CartesianFrame3D(name)
    inertia = SpatialInertia(frame, SDiagonal(0., 0, 0), SVector(0., 0, 0), 0.0)
    body = RigidBody(inertia)
    parent = findbody(full_model, name[1:6])
    joint = Joint(string(parent, "_to_", name), Fixed{Float64}())
    pose = Transform3D(frame_before(joint), default_frame(parent), orientation, SVector(offset...))
    attach!(full_model, parent, body, joint, joint_pose = pose)
end

mvis_full = MechanismVisualizer(full_model, Skeleton(), vis[:full])
copy!(mvis_full, init_atlas!(MechanismState(full_model)))
for bodyname in [
        "r_hand_mount",
        "l_hand_mount",
        "r_foot_sole",
        "l_foot_sole",
        "pelvis"
    ]
    setelement!(mvis_full, default_frame(findbody(full_model, bodyname)))
end

lqrsol = let params = MPCParams(reduced_model)
    params.Δt = 0.05
    LQRSolution(reduced_model, params)
end
# Out:
# (::LQRSolution) (generic function with 2 methods)
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# WARNING: Method definition (::Type{QPControl.ContactPoint{N}})(Union{RigidBodyDynamics.Spatial.Point3D{V} where V<:(AbstractArray{T, 1} where T), SimpleQP.Parameter{#s346, F, InPlace} where InPlace where F where #s346<:(RigidBodyDynamics.Spatial.Point3D{V} where V<:(AbstractArray{T, 1} where T))}, Union{RigidBodyDynamics.Spatial.FreeVector3D{V} where V<:(AbstractArray{T, 1} where T), SimpleQP.Parameter{#s345, F, InPlace} where InPlace where F where #s345<:(RigidBodyDynamics.Spatial.FreeVector3D{V} where V<:(AbstractArray{T, 1} where T))}, Union{Float64, SimpleQP.Parameter{Float64, F, InPlace} where InPlace where F}, RigidBodyDynamics.MechanismState{X, M, C, JointCollection} where JointCollection where C where M where X, SimpleQP.Model{T, O} where O<:MathOptInterface.AbstractOptimizer where T) in module QPControl at /home/rdeits/locomotion/explorations/learning-mpc-2/packages/v0.6/QPControl/src/contacts.jl:47 overwritten at /home/rdeits/locomotion/explorations/learning-mpc-2/packages/v0.6/QPControl/src/contacts.jl:47.
# WARNING: Method definition checkstatus(SimpleQP.Model{T, O} where O<:MathOptInterface.AbstractOptimizer where T) in module QPControl at /home/rdeits/locomotion/explorations/learning-mpc-2/packages/v0.6/QPControl/src/lowlevel/momentum.jl:84 overwritten at /home/rdeits/locomotion/explorations/learning-mpc-2/packages/v0.6/QPControl/src/lowlevel/momentum.jl:84.

# %%
mpc = QPControl.MPCController{QPControl.ContactPoint{4}}(
    mechanism(reduced_model),
    Gurobi.Optimizer(OutputFlag=0, TimeLimit=1)
)
copy!(mpc.state, nominal_state(reduced_model)) # ensure IKMimic has a good starting point
stage = addstage!(mpc, Δt)
floor = HalfSpace3D(Point3D(root_frame(mechanism(reduced_model)), 0., 0, 0),
    FreeVector3D(root_frame(mechanism(reduced_model)), 0., 0, 1))

for bodyname in ["r_foot_sole", "l_foot_sole"]
    body = findbody(mechanism(reduced_model), bodyname)
    position = Point3D(default_frame(body), 0., 0, 0)
    μ = 0.4
    contact = addcontact!(mpc, stage, position, floor, μ, 
        QPControl.LCPContact(separation_atol=1e-3),
#         QPControl.BooleanContact(separation_atol=1e-3)
    )
    contact.maxnormalforce[] = 1e6
end

objective = 0
for stage in mpc.stages
    x̄ = @expression vcat(stage.q, stage.v) - lqrsol.x0
    ū = @expression stage.u - lqrsol.u0
#     ū = stage.u
#     ū = stage.v̇
    objective = @expression objective + x̄' * lqrsol.Q * x̄ 
    objective = @expression objective + ū' * lqrsol.R * ū
    for contact in stage.contacts
        contact.weight[] = 1e-9
        objective = @expression objective + QPControl.objectiveterm(contact, mpc.qpmodel)
    end
end
x̄ = @expression vcat(last(mpc.stages).q, last(mpc.stages).v) - lqrsol.x0
objective = @expression objective + x̄' * lqrsol.S * x̄;
@objective mpc.qpmodel Minimize objective

momentum = MomentumBasedController{4}(full_model, Gurobi.Optimizer(OutputFlag=0),
    floatingjoint = findjoint(full_model, "pelvis_to_world")
)

for body in bodies(full_model)
    for point in RigidBodyDynamics.contact_points(body)
        position = location(point)
        normal = FreeVector3D(default_frame(body), 0.0, 0.0, 1.0)
        μ = point.model.friction.μ
        contact = addcontact!(momentum, body, position, normal, μ)
        contact.maxnormalforce[] = 1e6
        contact.weight[] = 1e-3
    end
end


task_map = Vector{Tuple{RigidBody{Float64}, QPControl.AbstractMotionTask}}()

for bodyname in ["pelvis", "r_hand_mount", "l_hand_mount"]
    body = findbody(full_model, bodyname)
    task = QPControl.PointAccelerationTask(
            full_model,
            path(full_model, root_body(full_model), body),
            Point3D(default_frame(body), 0., 0, 0)
            )
    addtask!(momentum, task)
    push!(task_map, (findbody(mechanism(reduced_model), bodyname), task))
end

oriented_bodies = [
    "pelvis",
    "r_foot_sole",
    "l_foot_sole"
]

orientation_control_tasks = Vector{AngularAccelerationTask}()

for bodyname in oriented_bodies
    body = findbody(full_model, bodyname)
    task = QPControl.AngularAccelerationTask(
            full_model,
            path(full_model, root_body(full_model), body)
            )
    addtask!(momentum, task)
    push!(orientation_control_tasks, task)
end

for joint in tree_joints(full_model)
    regularize!(momentum, joint, 1e-2)
end

xstar_full = init_atlas!(MechanismState(full_model))
joint_tasks = Vector{Tuple{JointID, Float64, JointAccelerationTask}}()
# for joint in tree_joints(full_model)
#     if contains(string(joint), "arm") || contains(string(joint), "back")
#         ref = configuration(xstar_full, joint)[]
#         id = JointID(joint)
#         task = JointAccelerationTask(joint)
#         addtask!(momentum, task, 1e-2)
#         push!(joint_tasks, (id, ref, task))
#     end
# end

matching_bodies = [
    "pelvis",
    "r_foot_sole",
    "l_foot_sole",
    "r_hand_mount",
    "l_hand_mount"
]
ik_workspace = IKMimic.IKMimicWorkspace(init_atlas!(MechanismState(full_model)), 
    nominal_state(reduced_model), matching_bodies, ["pelvis"])

mapped = LearningMPC.MappedController(
    mpc,
    momentum,
    task_map,
    orientation_control_tasks,
    joint_tasks,
    ik_workspace
)

highlevel = let mapped=mapped, mvis_full=mvis_full, mvis_reduced=mvis_reduced
    function (τ, t, x)
        copy!(mvis_full, x)
        try
            mapped(τ, t, x)
        finally
            set_configuration!(mvis_reduced, mapped.ik_workspace.x2[1:num_positions(mvis_reduced.state)])
    #         copy!(mvis_reduced, mapped.ik_workspace.x2)
        end
        sleep(0.01)
#         τ .= 0
    end
end
# Out:
# (::#51) (generic function with 1 method)
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# WARNING: Method definition (::LearningMPC.MappedController{C1<:(QPControl.MPCController{C, O, M, S} where S<:(RigidBodyDynamics.MechanismState{X, M, C, JointCollection} where JointCollection where C where M where X) where M<:(RigidBodyDynamics.Mechanism{T} where T) where O<:MathOptInterface.AbstractOptimizer where C), C2<:(QPControl.MomentumBasedController{N, O, S} where S<:(RigidBodyDynamics.MechanismState{X, M, C, JointCollection} where JointCollection where C where M where X) where O<:MathOptInterface.AbstractOptimizer where N)})(AbstractArray{T, 1} where T, Real, Union{AbstractArray{T, 1} where T, RigidBodyDynamics.MechanismState{X, M, C, JointCollection} where JointCollection where C where M where X}) in module LearningMPC at /home/rdeits/locomotion/explorations/learning-mpc-2/packages/v0.6/LearningMPC/src/mapped_control.jl:45 overwritten at /home/rdeits/locomotion/explorations/learning-mpc-2/packages/v0.6/LearningMPC/src/mapped_control.jl:45.

# %%
state = init_atlas!(MechanismState(full_model))
# set_velocity!(state, findjoint(full_model, "pelvis_to_world"), 
#     [-0.1, 0, 0])
problem = LearningMPC.simulation_problem(state, highlevel, Δt, 2.0; damping_kd=1.0)

sol = RigidBodySim.solve(problem, Tsit5(), abs_tol = 1e-8, dt = 1e-6)
setanimation!(mvis_full, sol)
# Out:
# p̈ref = FreeVector3D in "world": [4.36873e-22, 7.13468e-6, -9.88534]
# p̈ref = FreeVector3D in "world": [3.72086e-22, 42.9749, -52.3938]
# p̈ref = FreeVector3D in "world": [3.72086e-22, -42.975, -52.3938]
# p̈ref = FreeVector3D in "world": [-8.5644e-18, -0.139867, -41.8794]
# p̈ref = FreeVector3D in "world": [-9.53957e-18, 30.357, -90.7864]
# p̈ref = FreeVector3D in "world": [-9.53973e-18, -29.4675, -91.6489]
# p̈ref = FreeVector3D in "world": [-4.76884e-17, -0.77881, -46.1087]
# p̈ref = FreeVector3D in "world": [-5.44524e-17, 56.3422, -53.0616]
# p̈ref = FreeVector3D in "world": [-5.44553e-17, -55.9688, -58.6217]
# p̈ref = FreeVector3D in "world": [-2.03773e-16, -3.32787, -46.1206]
# p̈ref = FreeVector3D in "world": [-2.34693e-16, 47.8922, -45.4601]
# p̈ref = FreeVector3D in "world": [-2.34717e-16, -43.7053, -62.6569]
# p̈ref = FreeVector3D in "world": [-8.48894e-16, -13.8635, -47.1912]
# p̈ref = FreeVector3D in "world": [-9.77109e-16, 46.5408, -4.04631]
# p̈ref = FreeVector3D in "world": [-9.77582e-16, -28.4808, -76.2876]
# p̈ref = FreeVector3D in "world": [-2.48307e-15, -40.5516, -48.7065]
# p̈ref = FreeVector3D in "world": [-2.92173e-15, -9.54652, 56.8119]
# p̈ref = FreeVector3D in "world": [-2.92506e-15, -25.7674, -92.8235]
# p̈ref = FreeVector3D in "world": [-5.969e-15, -97.4812, -49.3901]
# p̈ref = FreeVector3D in "world": [-7.1046e-15, -27.6898, 75.1053]
# p̈ref = FreeVector3D in "world": [-7.10536e-15, -24.5587, -91.5713]
# p̈ref = FreeVector3D in "world": [-9.44451e-15, -154.241, -43.7995]
# p̈ref = FreeVector3D in "world": [-1.12838e-14, -26.205, 73.4915]
# p̈ref = FreeVector3D in "world": [-1.12458e-14, -23.8206, -90.7348]
# p̈ref = FreeVector3D in "world": [-9.26586e-15, -151.323, -13.382]
# p̈ref = FreeVector3D in "world": [-1.10597e-14, -25.1367, 72.2855]
# p̈ref = FreeVector3D in "world": [-1.10424e-14, -24.7857, -92.091]
# p̈ref = FreeVector3D in "world": [-1.08946e-14, -177.922, -5.17167]
# p̈ref = FreeVector3D in "world": [-1.30037e-14, -24.3566, 71.276]
# p̈ref = FreeVector3D in "world": [-1.30081e-14, -24.369, -92.012]
# p̈ref = FreeVector3D in "world": [-1.40848e-14, -230.022, -21.4017]
# p̈ref = FreeVector3D in "world": [-1.67705e-14, -23.828, 70.5189]
# p̈ref = FreeVector3D in "world": [-1.67827e-14, -22.8114, -90.5161]
# p̈ref = FreeVector3D in "world": [-1.37185e-14, -224.04, 30.5153]
# p̈ref = FreeVector3D in "world": [-1.62369e-14, 43.7516, 3.31241]
# p̈ref = FreeVector3D in "world": [-1.62594e-14, -24.6758, -92.726]
# p̈ref = FreeVector3D in "world": [-1.18982e-14, -194.312, -7.16627]
# p̈ref = FreeVector3D in "world": [-1.40338e-14, 13.7579, -33.6514]
# p̈ref = FreeVector3D in "world": [-1.40479e-14, -24.161, -91.8729]
# p̈ref = FreeVector3D in "world": [-1.03644e-14, -169.264, 22.1329]
# p̈ref = FreeVector3D in "world": [-1.23337e-14, -22.8892, 69.9801]
# p̈ref = FreeVector3D in "world": [-1.21877e-14, -25.5108, -93.6932]
# p̈ref = FreeVector3D in "world": [-9.04303e-15, -147.684, 28.2009]
# p̈ref = FreeVector3D in "world": [-1.07838e-14, -23.0964, 70.2327]
# p̈ref = FreeVector3D in "world": [-1.05234e-14, -25.8771, -94.3203]
# p̈ref = FreeVector3D in "world": [-6.08822e-15, -99.4282, 31.3454]
# p̈ref = FreeVector3D in "world": [-7.2447e-15, -79.562, 15.0947]
# p̈ref = FreeVector3D in "world": [-7.03184e-15, -26.1788, -95.2768]
# p̈ref = FreeVector3D in "world": [-6.70746e-15, -109.541, 31.0233]
# p̈ref = FreeVector3D in "world": [-7.98435e-15, -80.3134, 13.6945]
# p̈ref = FreeVector3D in "world": [-7.70148e-15, -25.6867, -95.1615]
# p̈ref = FreeVector3D in "world": [-6.8266e-15, -111.487, 18.5307]
# p̈ref = FreeVector3D in "world": [-8.16736e-15, -80.9152, 13.9335]
# p̈ref = FreeVector3D in "world": [-7.77574e-15, -25.1518, -94.7611]
# p̈ref = FreeVector3D in "world": [-6.18733e-15, -101.047, 13.957]
# p̈ref = FreeVector3D in "world": [-7.42574e-15, -81.4811, 14.1628]
# p̈ref = FreeVector3D in "world": [-6.95846e-15, -24.8233, -94.8227]
# p̈ref = FreeVector3D in "world": [-5.7221e-15, -93.449, 7.57778]
# p̈ref = FreeVector3D in "world": [-6.8931e-15, -82.1119, 14.3949]
# p̈ref = FreeVector3D in "world": [-6.36247e-15, -24.3913, -94.8299]
# p̈ref = FreeVector3D in "world": [-5.48628e-15, -89.5977, 1.11136]
# p̈ref = FreeVector3D in "world": [-6.63635e-15, -82.6486, 14.5331]
# p̈ref = FreeVector3D in "world": [-6.0314e-15, -23.919, -94.842]
# p̈ref = FreeVector3D in "world": [-5.32277e-15, -86.9274, -1.33887]
# p̈ref = FreeVector3D in "world": [-6.45674e-15, -82.9415, 14.4773]
# p̈ref = FreeVector3D in "world": [-5.77063e-15, -23.468, -95.0243]
# p̈ref = FreeVector3D in "world": [-5.23031e-15, -85.4175, -1.08042]
# p̈ref = FreeVector3D in "world": [-6.355e-15, -83.0606, 14.2842]
# p̈ref = FreeVector3D in "world": [-5.58024e-15, -23.0158, -95.3289]
# p̈ref = FreeVector3D in "world": [-5.18366e-15, -84.6557, 1.61845]
# p̈ref = FreeVector3D in "world": [-6.30045e-15, -83.0337, 13.9777]
# p̈ref = FreeVector3D in "world": [-5.43195e-15, -22.5559, -95.7456]
# p̈ref = FreeVector3D in "world": [-5.19188e-15, -84.7898, 6.23368]
# p̈ref = FreeVector3D in "world": [-6.30494e-15, -82.8848, 13.5773]
# p̈ref = FreeVector3D in "world": [-5.33547e-15, -22.0822, -96.2501]
# p̈ref = FreeVector3D in "world": [-5.25492e-15, -85.8194, 12.8433]
# p̈ref = FreeVector3D in "world": [-6.36792e-15, -82.6109, 13.0826]
# p̈ref = FreeVector3D in "world": [-5.28873e-15, -21.5952, -96.8402]
# p̈ref = FreeVector3D in "world": [-5.34681e-15, -87.3201, 21.0918]
# p̈ref = FreeVector3D in "world": [-6.45836e-15, -82.243, 12.5199]
# p̈ref = FreeVector3D in "world": [-5.26452e-15, -21.0935, -97.5025]
# p̈ref = FreeVector3D in "world": [-5.43332e-15, -88.7328, 30.3441]
# p̈ref = FreeVector3D in "world": [-6.53613e-15, -81.8333, 11.9307]
# p̈ref = FreeVector3D in "world": [-5.22991e-15, -20.5753, -98.2171]
# p̈ref = FreeVector3D in "world": [-5.51508e-15, -90.0681, 30.1998]
# p̈ref = FreeVector3D in "world": [-6.64092e-15, -81.9082, 11.7259]
# p̈ref = FreeVector3D in "world": [-5.21066e-15, -20.017, -98.6431]
# p̈ref = FreeVector3D in "world": [-5.6242e-15, -91.8502, 30.0335]
# p̈ref = FreeVector3D in "world": [-6.77765e-15, -81.986, 11.5292]
# p̈ref = FreeVector3D in "world": [-5.21686e-15, -19.4514, -99.0724]
# p̈ref = FreeVector3D in "world": [-5.75866e-15, -94.0461, 30.0356]
# p̈ref = FreeVector3D in "world": [-6.92963e-15, -76.0602, 5.91645]
# p̈ref = FreeVector3D in "world": [-5.24512e-15, -18.8795, -99.5082]
# p̈ref = FreeVector3D in "world": [-5.9576e-15, -97.295, 31.2606]
# p̈ref = FreeVector3D in "world": [-7.06203e-15, -30.2552, -35.5393]
# p̈ref = FreeVector3D in "world": [-5.32618e-15, -18.3089, -99.9819]
# p̈ref = FreeVector3D in "world": [-6.3079e-15, -103.016, 32.0836]
# p̈ref = FreeVector3D in "world": [-7.39343e-15, 6.54318, -68.5476]
# p̈ref = FreeVector3D in "world": [-5.54019e-15, -17.7328, -100.405]
# p̈ref = FreeVector3D in "world": [-4.52718e-15, -73.9344, 31.6889]
# p̈ref = FreeVector3D in "world": [-5.1613e-15, 37.802, -96.6317]
# p̈ref = FreeVector3D in "world": [-3.99567e-15, -83.5255, -56.7157]
# p̈ref = FreeVector3D in "world": [-4.39938e-15, -71.8473, 31.7209]
# p̈ref = FreeVector3D in "world": [-4.98095e-15, 37.7978, -96.5305]
# p̈ref = FreeVector3D in "world": [-3.81909e-15, -83.2445, -57.6964]
# p̈ref = FreeVector3D in "world": [-4.49588e-15, -73.4232, 26.0985]
# p̈ref = FreeVector3D in "world": [-5.10254e-15, 37.6229, -96.3124]
# p̈ref = FreeVector3D in "world": [-3.84916e-15, -82.9419, -58.4275]
# p̈ref = FreeVector3D in "world": [-4.89177e-15, -79.8887, 19.21]
# p̈ref = FreeVector3D in "world": [-5.59513e-15, 37.5248, -96.1722]
# p̈ref = FreeVector3D in "world": [-4.1361e-15, -82.6199, -59.0298]
# p̈ref = FreeVector3D in "world": [-5.77474e-15, -94.3086, 26.5755]
# p̈ref = FreeVector3D in "world": [-6.60355e-15, 38.3534, -96.7736]
# p̈ref = FreeVector3D in "world": [-4.79433e-15, -82.2963, -59.9632]
# p̈ref = FreeVector3D in "world": [-1.08529e-14, -177.241, 25.6793]
# p̈ref = FreeVector3D in "world": [-1.27297e-14, 40.6946, -98.8367]
# p̈ref = FreeVector3D in "world": [-8.9746e-15, -81.5895, -59.749]
# p̈ref = FreeVector3D in "world": [-1.18995e-14, -194.333, -15.5017]
# p̈ref = FreeVector3D in "world": [-1.41196e-14, 38.9333, -97.6742]
# p̈ref = FreeVector3D in "world": [-9.88527e-15, -80.8066, -59.0392]
# p̈ref = FreeVector3D in "world": [-1.48244e-14, -242.101, 5.29943]
# p̈ref = FreeVector3D in "world": [-1.75056e-14, 42.1756, -99.8415]
# p̈ref = FreeVector3D in "world": [-1.21268e-14, -60.4187, -25.7376]
# p̈ref = FreeVector3D in "world": [-1.41052e-14, -230.355, -20.2377]
# p̈ref = FreeVector3D in "world": [-1.71905e-14, -27.7937, 68.5684]
# p̈ref = FreeVector3D in "world": [-1.13311e-14, -11.9634, -100.365]
# p̈ref = FreeVector3D in "world": [-1.44465e-14, -235.93, -20.4225]
# p̈ref = FreeVector3D in "world": [-1.76323e-14, -27.0989, 68.2445]
# p̈ref = FreeVector3D in "world": [-1.13503e-14, -12.1087, -100.632]
# p̈ref = FreeVector3D in "world": [-1.69932e-14, -277.52, -22.3283]
# p̈ref = FreeVector3D in "world": [-2.08043e-14, -24.9498, 67.0073]
# p̈ref = FreeVector3D in "world": [-1.30343e-14, -12.5111, -100.538]
# p̈ref = FreeVector3D in "world": [-2.14636e-14, -350.527, -25.7234]
# p̈ref = FreeVector3D in "world": [-2.63959e-14, -21.2157, 64.8504]
# p̈ref = FreeVector3D in "world": [-1.61035e-14, -13.2407, -100.289]
# p̈ref = FreeVector3D in "world": [-6.8697e-15, -112.191, 35.8287]
# p̈ref = FreeVector3D in "world": [-8.17926e-15, -80.4222, 8.31906]
# p̈ref = FreeVector3D in "world": [-4.74803e-15, -33.9481, -92.1804]
# p̈ref = FreeVector3D in "world": [1.73461e-15, 28.3283, 53.7866]
# p̈ref = FreeVector3D in "world": [2.74077e-15, 38.1514, -93.4161]
# p̈ref = FreeVector3D in "world": [1.08272e-15, 3.96617, 85.6978]
# p̈ref = FreeVector3D in "world": [9.45129e-15, 154.351, 70.2042]
# p̈ref = FreeVector3D in "world": [1.21365e-14, 34.9042, -91.0621]
# p̈ref = FreeVector3D in "world": [6.84698e-15, 2.64977, 83.2816]
# p̈ref = FreeVector3D in "world": [2.28272e-14, 372.796, 125.816]
# p̈ref = FreeVector3D in "world": [2.81985e-14, 32.7977, -88.8627]
# p̈ref = FreeVector3D in "world": [1.71158e-14, -2.29245, 76.045]
# p̈ref = FreeVector3D in "world": [3.90885e-14, 638.363, 182.277]
# p̈ref = FreeVector3D in "world": [4.71572e-14, 33.1956, -87.2207]
# p̈ref = FreeVector3D in "world": [2.97386e-14, -11.6772, 65.3493]
# p̈ref = FreeVector3D in "world": [6.3845e-14, 1042.67, 241.568]
# p̈ref = FreeVector3D in "world": [7.43427e-14, 44.4283, -86.8272]
# p̈ref = FreeVector3D in "world": [4.96948e-14, -34.9712, 44.5986]
# p̈ref = FreeVector3D in "world": [8.6887e-14, 1418.97, 271.967]
# p̈ref = FreeVector3D in "world": [9.77259e-14, 67.095, -88.9725]
# p̈ref = FreeVector3D in "world": [6.87508e-14, -63.9069, 21.1992]
# p̈ref = FreeVector3D in "world": [4.55707e-14, 744.226, 110.482]
# p̈ref = FreeVector3D in "world": [5.23682e-14, 40.1276, -85.8131]
# p̈ref = FreeVector3D in "world": [3.30559e-14, -18.1737, 63.9995]
# p̈ref = FreeVector3D in "world": [3.50394e-14, 572.236, 99.2823]
# p̈ref = FreeVector3D in "world": [4.01574e-14, 38.5275, -87.0369]
# p̈ref = FreeVector3D in "world": [2.48093e-14, -13.1793, 70.5783]
# p̈ref = FreeVector3D in "world": [2.88163e-14, 470.606, 121.185]
# p̈ref = FreeVector3D in "world": [3.33515e-14, 36.2674, -89.0395]
# p̈ref = FreeVector3D in "world": [2.00033e-14, -9.68768, 73.491]
# p̈ref = FreeVector3D in "world": [2.24175e-14, 366.106, 147.692]
# p̈ref = FreeVector3D in "world": [2.64547e-14, 35.1366, -91.6059]
# p̈ref = FreeVector3D in "world": [1.52275e-14, -6.83394, 75.9082]
# p̈ref = FreeVector3D in "world": [2.33969e-14, 382.1, 160.269]
# p̈ref = FreeVector3D in "world": [2.73901e-14, 35.0805, -92.067]
# p̈ref = FreeVector3D in "world": [1.56381e-14, -7.28253, 75.2987]
# p̈ref = FreeVector3D in "world": [2.40572e-14, 392.883, 169.46]
# p̈ref = FreeVector3D in "world": [2.79254e-14, 34.8999, -92.5384]
# p̈ref = FreeVector3D in "world": [1.57412e-14, -7.46935, 74.9833]
# p̈ref = FreeVector3D in "world": [2.45976e-14, 401.709, 172.902]
# p̈ref = FreeVector3D in "world": [2.82436e-14, 34.6758, -92.8766]
# p̈ref = FreeVector3D in "world": [1.56759e-14, -7.5046, 74.9692]
# p̈ref = FreeVector3D in "world": [2.45103e-14, 400.284, 169.664]
# p̈ref = FreeVector3D in "world": [2.78031e-14, 34.4389, -93.1335]
# p̈ref = FreeVector3D in "world": [1.51273e-14, -7.28729, 75.53]
# p̈ref = FreeVector3D in "world": [2.30252e-14, 376.03, 158.047]
# p̈ref = FreeVector3D in "world": [2.58106e-14, 34.1803, -93.3532]
# p̈ref = FreeVector3D in "world": [1.36654e-14, -6.80781, 77.031]
# p̈ref = FreeVector3D in "world": [1.88699e-14, 308.169, 135.933]
# p̈ref = FreeVector3D in "world": [2.09959e-14, 33.8437, -93.6276]
# p̈ref = FreeVector3D in "world": [1.06454e-14, -6.28464, 79.9107]
# p̈ref = FreeVector3D in "world": [1.16514e-14, 190.281, 105.265]
# p̈ref = FreeVector3D in "world": [1.3132e-14, 33.242, -94.0868]
# p̈ref = FreeVector3D in "world": [6.09033e-15, -6.3664, 83.8967]
# p̈ref = FreeVector3D in "world": [8.12311e-16, 13.266, 76.9568]
# p̈ref = FreeVector3D in "world": [1.91356e-15, 32.6558, -95.5292]
# p̈ref = FreeVector3D in "world": [1.02059e-15, -72.1719, -82.3317]
# p̈ref = FreeVector3D in "world": [-1.27126e-14, -207.613, -0.212936]
# p̈ref = FreeVector3D in "world": [-1.29139e-14, -27.3662, 77.3632]
# p̈ref = FreeVector3D in "world": [-5.79621e-15, -0.35957, -105.077]
# p̈ref = FreeVector3D in "world": [-3.87593e-14, -632.988, -35.8084]
# p̈ref = FreeVector3D in "world": [-3.84106e-14, -22.5342, 71.991]
# p̈ref = FreeVector3D in "world": [-1.72578e-14, -12.9895, -103.614]
# p̈ref = FreeVector3D in "world": [-3.65712e-15, -59.7253, -51.2469]
# p̈ref = FreeVector3D in "world": [-3.22175e-15, 30.2069, -92.8516]
# p̈ref = FreeVector3D in "world": [-1.28056e-15, -3.31733, -102.802]
# p̈ref = FreeVector3D in "world": [-5.87428e-15, -95.9342, -4.03756]
# p̈ref = FreeVector3D in "world": [-5.0701e-15, 29.1141, -94.636]
# p̈ref = FreeVector3D in "world": [-2.32033e-15, -70.4548, -81.0157]
# p̈ref = FreeVector3D in "world": [-1.1827e-14, -193.149, 23.6642]
# p̈ref = FreeVector3D in "world": [-1.00015e-14, 27.2587, -97.1048]
# p̈ref = FreeVector3D in "world": [-4.92543e-15, -69.585, -81.1857]
# p̈ref = FreeVector3D in "world": [-2.2679e-14, -370.376, 50.6258]
# p̈ref = FreeVector3D in "world": [-1.88195e-14, 23.7034, -100.806]
# p̈ref = FreeVector3D in "world": [-9.85825e-15, -67.4011, -79.8343]
# p̈ref = FreeVector3D in "world": [-2.68364e-14, -438.271, 33.1365]
# p̈ref = FreeVector3D in "world": [-2.14642e-14, 22.2056, -102.036]
# p̈ref = FreeVector3D in "world": [-1.17148e-14, 8.84434, -102.885]
# p̈ref = FreeVector3D in "world": [-4.89798e-14, -799.9, 27.2044]
# p̈ref = FreeVector3D in "world": [-3.92784e-14, -31.5651, 74.9145]
# p̈ref = FreeVector3D in "world": [-2.19054e-14, 8.19747, -99.0721]
# p̈ref = FreeVector3D in "world": [-7.01402e-14, -1145.48, -71.2537]
# p̈ref = FreeVector3D in "world": [-5.37191e-14, -34.5641, 71.5758]
# p̈ref = FreeVector3D in "world": [-3.19117e-14, 6.31675, -95.3821]
# p̈ref = FreeVector3D in "world": [-7.45775e-14, -1217.94, -121.485]
# p̈ref = FreeVector3D in "world": [-5.35795e-14, -35.1445, 72.1306]
# p̈ref = FreeVector3D in "world": [-3.48806e-14, 10.0495, -92.883]
# p̈ref = FreeVector3D in "world": [-8.30146e-14, -1355.73, -147.142]
# p̈ref = FreeVector3D in "world": [-5.54688e-14, -36.8628, 69.6386]
# p̈ref = FreeVector3D in "world": [-4.02471e-14, 12.9268, -91.524]
# p̈ref = FreeVector3D in "world": [-7.19362e-14, -1174.81, -151.088]
# p̈ref = FreeVector3D in "world": [-4.27143e-14, 61.9119, -67.9714]
# p̈ref = FreeVector3D in "world": [-3.76537e-14, 26.4547, -86.2278]
# p̈ref = FreeVector3D in "world": [-7.43313e-14, -1213.92, -190.353]
# p̈ref = FreeVector3D in "world": [-3.99115e-14, 60.363, -71.328]
# p̈ref = FreeVector3D in "world": [-4.08266e-14, 27.4203, -85.1947]
# p̈ref = FreeVector3D in "world": [-7.75824e-14, -1267.02, -215.489]
# p̈ref = FreeVector3D in "world": [-3.81332e-14, -12.4517, 24.4907]
# p̈ref = FreeVector3D in "world": [-4.46565e-14, 29.1798, -84.4302]
# p̈ref = FreeVector3D in "world": [-8.09383e-14, -1321.82, -222.564]
# p̈ref = FreeVector3D in "world": [-3.52375e-14, -49.2941, 72.4331]
# p̈ref = FreeVector3D in "world": [-4.8641e-14, 31.2085, -84.2254]
# p̈ref = FreeVector3D in "world": [-8.38644e-14, -1369.61, -238.257]
# p̈ref = FreeVector3D in "world": [-3.10532e-14, -51.0782, 70.4513]
# p̈ref = FreeVector3D in "world": [-5.26748e-14, 32.4507, -84.1766]
# p̈ref = FreeVector3D in "world": [-8.48433e-14, -1385.6, -259.308]
# p̈ref = FreeVector3D in "world": [-2.58626e-14, -51.8114, 69.7874]
# p̈ref = FreeVector3D in "world": [-5.57494e-14, 32.3616, -84.3596]
# p̈ref = FreeVector3D in "world": [-8.31499e-14, -1357.94, -270.349]
# p̈ref = FreeVector3D in "world": [-1.90345e-14, -18.5796, 16.7335]
# p̈ref = FreeVector3D in "world": [-5.69846e-14, 31.1507, -84.9885]
# p̈ref = FreeVector3D in "world": [-7.88996e-14, -1288.53, -269.821]
# p̈ref = FreeVector3D in "world": [-1.10209e-14, 46.7191, -91.4656]
# p̈ref = FreeVector3D in "world": [-5.61453e-14, 29.1094, -86.0307]
# p̈ref = FreeVector3D in "world": [-7.45781e-14, -1217.95, -266.071]
# p̈ref = FreeVector3D in "world": [-5.47943e-15, 47.6176, -91.6856]
# p̈ref = FreeVector3D in "world": [-5.48905e-14, 26.8398, -87.262]
# p̈ref = FreeVector3D in "world": [-7.10525e-14, -1160.38, -251.24]
# p̈ref = FreeVector3D in "world": [-6.72675e-16, 48.1427, -92.3682]
# p̈ref = FreeVector3D in "world": [-5.36698e-14, 24.4119, -89.0586]
# p̈ref = FreeVector3D in "world": [-5.27393e-14, -861.297, -214.902]
# p̈ref = FreeVector3D in "world": [3.78706e-15, -18.8438, -121.349]
# p̈ref = FreeVector3D in "world": [-4.45383e-14, -4.88009, 102.314]
# p̈ref = FreeVector3D in "world": [-3.57805e-14, -584.34, -176.995]
# p̈ref = FreeVector3D in "world": [4.51545e-15, -11.8626, -115.141]
# p̈ref = FreeVector3D in "world": [-3.22478e-14, -9.03779, 99.6001]
# p̈ref = FreeVector3D in "world": [-3.95877e-14, -646.516, -158.018]
# p̈ref = FreeVector3D in "world": [7.76755e-15, -16.4114, -119.391]
# p̈ref = FreeVector3D in "world": [-3.50899e-14, -8.48363, 97.9717]
# p̈ref = FreeVector3D in "world": [-5.63588e-14, -920.408, -246.302]
# p̈ref = FreeVector3D in "world": [1.21148e-14, 51.8228, -95.3644]
# p̈ref = FreeVector3D in "world": [-4.5835e-14, 19.7233, -93.9605]
# p̈ref = FreeVector3D in "world": [-2.11037e-14, -344.65, -123.811]
# p̈ref = FreeVector3D in "world": [6.1627e-15, -9.07012, -113.217]
# p̈ref = FreeVector3D in "world": [-2.15905e-14, -11.3442, 96.4556]
# p̈ref = FreeVector3D in "world": [-1.78547e-14, -291.589, -110.74]
# p̈ref = FreeVector3D in "world": [6.02369e-15, -8.53873, -112.883]
# p̈ref = FreeVector3D in "world": [-1.91307e-14, -11.8391, 95.7786]
# p̈ref = FreeVector3D in "world": [-1.76382e-14, -288.054, -112.919]
# p̈ref = FreeVector3D in "world": [7.0854e-15, -9.82878, -113.493]
# p̈ref = FreeVector3D in "world": [-1.92307e-14, -13.2931, 95.249]
# p̈ref = FreeVector3D in "world": [-1.75052e-14, -285.881, -115.482]
# p̈ref = FreeVector3D in "world": [8.16232e-15, -11.1591, -114.104]
# p̈ref = FreeVector3D in "world": [-1.93774e-14, -14.6563, 94.7603]
# p̈ref = FreeVector3D in "world": [-1.73401e-14, -283.185, -118.056]
# p̈ref = FreeVector3D in "world": [9.44809e-15, -11.8219, -114.67]
# p̈ref = FreeVector3D in "world": [-1.93416e-14, -17.2599, 93.5974]
# p̈ref = FreeVector3D in "world": [-1.71594e-14, -280.235, -120.069]
# p̈ref = FreeVector3D in "world": [1.05318e-14, -12.5493, -115.157]
# p̈ref = FreeVector3D in "world": [-1.92256e-14, -19.5382, 92.5815]
# p̈ref = FreeVector3D in "world": [-1.6973e-14, -277.19, -121.853]
# p̈ref = FreeVector3D in "world": [1.15251e-14, -13.1738, -115.564]
# p̈ref = FreeVector3D in "world": [-1.90333e-14, -21.7359, 91.5888]
# p̈ref = FreeVector3D in "world": [-1.0007e-14, -163.427, -41.0762]
# p̈ref = FreeVector3D in "world": [8.93788e-15, -11.0246, -114.637]
# p̈ref = FreeVector3D in "world": [-1.15511e-14, -23.1461, 87.6858]
# p̈ref = FreeVector3D in "world": [-8.06751e-15, -131.752, 25.6443]
# p̈ref = FreeVector3D in "world": [5.83736e-14, 597.222, -1817.84]
# p̈ref = FreeVector3D in "world": [-2.83075e-15, 16.5071, -108.445]
# p̈ref = FreeVector3D in "world": [-5.70489e-15, -93.1679, 36.7277]
# p̈ref = FreeVector3D in "world": [5.29295e-14, 471.569, -1662.91]
# p̈ref = FreeVector3D in "world": [-6.1158e-16, 17.2931, -108.695]
# p̈ref = FreeVector3D in "world": [-4.37201e-15, -71.4003, 43.5253]
# p̈ref = FreeVector3D in "world": [4.96243e-14, 422.621, -1563.97]
# p̈ref = FreeVector3D in "world": [6.36409e-16, 18.2395, -108.619]
# p̈ref = FreeVector3D in "world": [-2.93591e-15, -47.947, 50.7352]
# p̈ref = FreeVector3D in "world": [4.5724e-14, 376.742, -1452.85]
# p̈ref = FreeVector3D in "world": [1.95329e-15, 19.2002, -108.572]
# p̈ref = FreeVector3D in "world": [-3.55248e-16, -5.80164, 23.8927]
# p̈ref = FreeVector3D in "world": [4.11956e-14, 336.409, -1348.12]
# p̈ref = FreeVector3D in "world": [2.73512e-15, -34.159, -97.4745]
# p̈ref = FreeVector3D in "world": [9.64567e-16, 15.7526, 33.1714]
# p̈ref = FreeVector3D in "world": [3.72464e-14, 301.525, -1253.45]
# p̈ref = FreeVector3D in "world": [4.45234e-15, 20.8494, -106.685]
# p̈ref = FreeVector3D in "world": [2.35381e-15, 38.4407, 40.6245]
# p̈ref = FreeVector3D in "world": [3.28145e-14, 263.207, -1138.22]
# p̈ref = FreeVector3D in "world": [5.62732e-15, 21.9088, -106.604]
# p̈ref = FreeVector3D in "world": [3.40566e-15, 55.6186, 46.5576]
# p̈ref = FreeVector3D in "world": [2.93678e-14, 234.272, -1049.5]
# p̈ref = FreeVector3D in "world": [6.48107e-15, 23.0355, -106.478]
# p̈ref = FreeVector3D in "world": [4.3755e-15, 71.4574, 52.154]
# p̈ref = FreeVector3D in "world": [2.6097e-14, 208.446, -966.342]
# p̈ref = FreeVector3D in "world": [7.23495e-15, 24.1877, -106.355]
# p̈ref = FreeVector3D in "world": [5.03012e-15, 82.148, 56.2944]
# p̈ref = FreeVector3D in "world": [2.3878e-14, 190.955, -910.093]
# p̈ref = FreeVector3D in "world": [7.70912e-15, 25.322, -106.206]
# p̈ref = FreeVector3D in "world": [5.84075e-15, 95.3867, 61.803]
# p̈ref = FreeVector3D in "world": [2.02109e-14, 245.467, -809.384]
# p̈ref = FreeVector3D in "world": [8.22848e-15, 26.4862, -105.951]
# p̈ref = FreeVector3D in "world": [6.99134e-15, 114.177, 68.1895]
# p̈ref = FreeVector3D in "world": [1.57532e-14, 215.65, -698.72]
# p̈ref = FreeVector3D in "world": [9.00566e-15, 27.7082, -105.793]
# p̈ref = FreeVector3D in "world": [7.37395e-15, 120.426, 69.9301]
# p̈ref = FreeVector3D in "world": [1.22593e-14, 191.814, -608.569]
# p̈ref = FreeVector3D in "world": [9.0848e-15, 28.8582, -105.264]
# p̈ref = FreeVector3D in "world": [8.27753e-15, 135.182, 74.9829]
# p̈ref = FreeVector3D in "world": [8.52792e-15, 168.213, -516.242]
# p̈ref = FreeVector3D in "world": [9.5808e-15, 30.1315, -105.196]
# p̈ref = FreeVector3D in "world": [9.48629e-15, 154.923, 81.0065]
# p̈ref = FreeVector3D in "world": [3.601e-15, 137.423, -394.408]
# p̈ref = FreeVector3D in "world": [1.02263e-14, 31.4976, -105.1]
# p̈ref = FreeVector3D in "world": [9.68089e-15, 158.101, 82.5447]
# p̈ref = FreeVector3D in "world": [2.85369e-15, 133.155, -375.887]
# p̈ref = FreeVector3D in "world": [1.01559e-14, 32.6141, -104.978]
# p̈ref = FreeVector3D in "world": [9.92644e-15, 162.111, 84.2963]
# p̈ref = FreeVector3D in "world": [1.84073e-15, 127.206, -350.427]
# p̈ref = FreeVector3D in "world": [1.01116e-14, 33.7254, -104.85]
# p̈ref = FreeVector3D in "world": [1.0219e-14, 166.889, 85.6267]
# p̈ref = FreeVector3D in "world": [2.25691e-16, 109.907, -309.622]
# p̈ref = FreeVector3D in "world": [1.00635e-14, 34.8584, -104.613]
# p̈ref = FreeVector3D in "world": [1.10584e-14, 180.598, 88.2405]
# p̈ref = FreeVector3D in "world": [-3.01104e-15, 15.9165, -235.176]
# p̈ref = FreeVector3D in "world": [1.03563e-14, 36.1665, -104.398]
# p̈ref = FreeVector3D in "world": [1.01233e-14, 165.327, 84.8526]
# p̈ref = FreeVector3D in "world": [4.09811e-16, 38.3678, -318.857]
# p̈ref = FreeVector3D in "world": [9.60439e-15, 36.8824, -103.997]
# p̈ref = FreeVector3D in "world": [1.04351e-14, 170.418, 86.3531]
# p̈ref = FreeVector3D in "world": [-1.03786e-15, 29.2115, -281.556]
# p̈ref = FreeVector3D in "world": [9.55275e-15, 37.9883, -103.736]
# p̈ref = FreeVector3D in "world": [1.05029e-14, 171.526, 86.9925]
# p̈ref = FreeVector3D in "world": [-1.38763e-15, 27.2556, -271.721]
# p̈ref = FreeVector3D in "world": [9.36959e-15, 39.02, -103.405]
# p̈ref = FreeVector3D in "world": [1.00659e-14, 164.388, 109.532]
# p̈ref = FreeVector3D in "world": [-3.23098e-15, 9.67587, -203.274]
# p̈ref = FreeVector3D in "world": [9.37404e-15, 40.6055, -104.641]
# p̈ref = FreeVector3D in "world": [1.0347e-14, 168.98, 123.856]
# p̈ref = FreeVector3D in "world": [-6.21177e-15, 11.2368, -114.265]
# p̈ref = FreeVector3D in "world": [9.46881e-15, 42.2349, -105.175]
# p̈ref = FreeVector3D in "world": [1.19406e-14, 195.004, 131.535]
# p̈ref = FreeVector3D in "world": [-1.20345e-14, 27.9777, 37.7318]
# p̈ref = FreeVector3D in "world": [9.85418e-15, 44.1926, -105.044]
# p̈ref = FreeVector3D in "world": [1.48227e-14, 242.073, 107.838]
# p̈ref = FreeVector3D in "world": [-1.5849e-14, 10.0779, 100.856]
# p̈ref = FreeVector3D in "world": [1.01741e-14, 45.519, -102.356]
# p̈ref = FreeVector3D in "world": [1.4861e-14, 242.698, 106.937]
# p̈ref = FreeVector3D in "world": [-1.5603e-14, 9.38004, 100.688]
# p̈ref = FreeVector3D in "world": [9.72038e-15, 47.2204, -101.121]
# p̈ref = FreeVector3D in "world": [1.47968e-14, 241.65, 105.073]
# p̈ref = FreeVector3D in "world": [-1.53081e-14, 8.95795, 100.616]
# p̈ref = FreeVector3D in "world": [9.14442e-15, 48.8004, -99.8178]
# p̈ref = FreeVector3D in "world": [1.43143e-14, 233.77, 99.6286]
# p̈ref = FreeVector3D in "world": [-1.49017e-14, 8.85709, 100.6]
# p̈ref = FreeVector3D in "world": [8.22559e-15, 49.8363, -98.6669]
# p̈ref = FreeVector3D in "world": [1.43022e-14, 233.572, 98.1972]
# p̈ref = FreeVector3D in "world": [-1.46226e-14, 7.89811, 100.4]
# p̈ref = FreeVector3D in "world": [7.69472e-15, 51.4499, -97.4157]
# p̈ref = FreeVector3D in "world": [1.4198e-14, 231.87, 95.8545]
# p̈ref = FreeVector3D in "world": [-1.43012e-14, 6.6854, 100.184]
# p̈ref = FreeVector3D in "world": [7.07654e-15, 52.9608, -96.1727]
# p̈ref = FreeVector3D in "world": [1.63373e-14, 266.808, 70.9237]
# p̈ref = FreeVector3D in "world": [-1.3287e-14, 5.17471, 100.757]
# p̈ref = FreeVector3D in "world": [7.47387e-15, 53.279, -94.0558]
# p̈ref = FreeVector3D in "world": [1.65358e-14, 270.051, 71.3264]
# p̈ref = FreeVector3D in "world": [-1.3013e-14, 4.42577, 100.902]
# p̈ref = FreeVector3D in "world": [6.80305e-15, 54.7742, -93.4306]
# p̈ref = FreeVector3D in "world": [1.67262e-14, 273.16, 71.7006]
# p̈ref = FreeVector3D in "world": [-1.27256e-14, 3.35179, 100.926]
# p̈ref = FreeVector3D in "world": [6.14806e-15, 56.3399, -92.6771]
# p̈ref = FreeVector3D in "world": [1.6933e-14, 276.537, 72.1405]
# p̈ref = FreeVector3D in "world": [-1.24245e-14, 1.84575, 100.881]
# p̈ref = FreeVector3D in "world": [5.53986e-15, 58.0412, -91.6936]
# p̈ref = FreeVector3D in "world": [1.71271e-14, 279.707, 72.3864]
# p̈ref = FreeVector3D in "world": [-1.2073e-14, 0.741383, 101.019]
# p̈ref = FreeVector3D in "world": [4.76453e-15, 59.6346, -90.9586]
# p̈ref = FreeVector3D in "world": [1.73492e-14, 283.334, 72.7984]
# p̈ref = FreeVector3D in "world": [-1.1697e-14, -0.27841, 101.212]
# p̈ref = FreeVector3D in "world": [3.94192e-15, 61.2666, -90.2974]
# p̈ref = FreeVector3D in "world": [6.43823e-14, 1051.44, 587.365]
# p̈ref = FreeVector3D in "world": [-3.72657e-14, -8.78663, -98.2594]
# p̈ref = FreeVector3D in "world": [-4.0438e-16, -18.4748, -30.7039]
# p̈ref = FreeVector3D in "world": [1.17046e-13, 1911.51, 1087.67]
# p̈ref = FreeVector3D in "world": [-7.54605e-14, 63.3814, -94.991]
# p̈ref = FreeVector3D in "world": [4.52626e-15, -44.2112, -177.736]
# p̈ref = FreeVector3D in "world": [9.34376e-14, 1525.95, 861.58]
# p̈ref = FreeVector3D in "world": [-5.56565e-14, 27.9174, -93.8014]
# p̈ref = FreeVector3D in "world": [-6.60597e-15, -24.7656, -104.795]
# p̈ref = FreeVector3D in "world": [7.92431e-14, 1294.14, 727.036]
# p̈ref = FreeVector3D in "world": [-4.41736e-14, 9.77225, -94.3482]
# p̈ref = FreeVector3D in "world": [-1.32476e-14, -16.5592, -66.2253]
# p̈ref = FreeVector3D in "world": [8.26484e-14, 1349.75, 759.551]
# p̈ref = FreeVector3D in "world": [-4.54191e-14, 15.1674, -93.5928]
# p̈ref = FreeVector3D in "world": [-1.88252e-14, -16.5773, -75.6534]
# p̈ref = FreeVector3D in "world": [8.62464e-14, 1408.51, 798.756]
# p̈ref = FreeVector3D in "world": [-4.73499e-14, 25.1419, -92.4181]
# p̈ref = FreeVector3D in "world": [-2.46157e-14, -18.8826, -87.4861]
# p̈ref = FreeVector3D in "world": [8.41945e-14, 1375.0, 787.261]
# p̈ref = FreeVector3D in "world": [-4.5977e-14, 29.5076, -91.4198]
# p̈ref = FreeVector3D in "world": [-2.98889e-14, -19.3317, -84.831]
# p̈ref = FreeVector3D in "world": [7.93543e-14, 1295.95, 747.94]
# p̈ref = FreeVector3D in "world": [-4.27488e-14, 26.4405, -91.1675]
# p̈ref = FreeVector3D in "world": [-3.44243e-14, -18.1366, -74.4449]
# p̈ref = FreeVector3D in "world": [6.61064e-14, 1079.6, 650.451]
# p̈ref = FreeVector3D in "world": [-3.73716e-14, 31.7781, -88.2061]
# p̈ref = FreeVector3D in "world": [-3.38301e-14, -32.4823, -54.7506]
# p̈ref = FreeVector3D in "world": [7.35003e-14, 1200.35, 741.8]
# p̈ref = FreeVector3D in "world": [-4.5482e-14, 53.8487, -84.2552]
# p̈ref = FreeVector3D in "world": [-3.98558e-14, -37.806, -77.5836]
# p̈ref = FreeVector3D in "world": [6.64319e-14, 1084.91, 689.917]
# p̈ref = FreeVector3D in "world": [-4.29685e-14, 50.1262, -83.7186]
# p̈ref = FreeVector3D in "world": [-4.11347e-14, -36.0066, -62.18]
# p̈ref = FreeVector3D in "world": [5.95374e-14, 972.32, 637.083]
# p̈ref = FreeVector3D in "world": [-4.02899e-14, 42.7407, -84.2337]
# p̈ref = FreeVector3D in "world": [-4.17562e-14, -35.2137, -49.1388]
# p̈ref = FreeVector3D in "world": [4.98736e-14, 814.497, 554.613]
# p̈ref = FreeVector3D in "world": [-3.53406e-14, 32.1735, -86.1864]
# p̈ref = FreeVector3D in "world": [-3.95937e-14, -37.7893, -32.3746]
# p̈ref = FreeVector3D in "world": [5.06322e-14, 826.886, 573.073]
# p̈ref = FreeVector3D in "world": [-3.76165e-14, 33.1519, -84.689]
# p̈ref = FreeVector3D in "world": [-4.29443e-14, -35.0163, -35.4769]
# p̈ref = FreeVector3D in "world": [5.65317e-14, 923.233, 655.683]
# p̈ref = FreeVector3D in "world": [-4.54064e-14, 45.3109, -80.9453]
# p̈ref = FreeVector3D in "world": [-4.94527e-14, -35.7261, -53.8069]
# p̈ref = FreeVector3D in "world": [5.4632e-14, 892.208, 654.541]
# p̈ref = FreeVector3D in "world": [-4.64942e-14, 43.9221, -80.6409]
# p̈ref = FreeVector3D in "world": [-5.1191e-14, -36.1492, -53.402]
# p̈ref = FreeVector3D in "world": [5.17071e-14, 844.441, 641.098]
# p̈ref = FreeVector3D in "world": [-4.66604e-14, 41.3709, -80.7606]
# p̈ref = FreeVector3D in "world": [-5.20735e-14, -36.1619, -50.1752]
# p̈ref = FreeVector3D in "world": [5.10499e-14, 833.707, 656.491]
# p̈ref = FreeVector3D in "world": [-4.94159e-14, 43.1573, -79.6902]
# p̈ref = FreeVector3D in "world": [-5.4396e-14, -37.4576, -53.4384]
# p̈ref = FreeVector3D in "world": [4.47596e-14, 730.98, 712.251]
# p̈ref = FreeVector3D in "world": [-1.98556e-14, 309.277, -1109.15]
# p̈ref = FreeVector3D in "world": [-5.23715e-14, -38.4812, -54.1786]
# p̈ref = FreeVector3D in "world": [3.45088e-14, 563.571, 793.051]
# p̈ref = FreeVector3D in "world": [3.1137e-14, 801.042, -2780.78]
# p̈ref = FreeVector3D in "world": [-4.74061e-14, -37.7336, -52.6785]
# p̈ref = FreeVector3D in "world": [2.12805e-14, 347.537, 784.587]
# p̈ref = FreeVector3D in "world": [6.99185e-14, 1160.49, -3858.82]
# p̈ref = FreeVector3D in "world": [-3.8635e-14, -43.2816, -42.6697]
# p̈ref = FreeVector3D in "world": [1.26861e-14, 207.18, 641.921]
# p̈ref = FreeVector3D in "world": [6.3465e-14, 970.182, -3337.01]
# p̈ref = FreeVector3D in "world": [-3.13179e-14, -49.4669, -25.3001]
# p̈ref = FreeVector3D in "world": [-7.78885e-17, -1.27202, 415.65]
# p̈ref = FreeVector3D in "world": [6.0005e-14, 752.156, -2704.9]
# p̈ref = FreeVector3D in "world": [-1.68935e-14, -63.2108, -0.478562]
# p̈ref = FreeVector3D in "world": [-1.10135e-14, -179.864, 200.998]
# p̈ref = FreeVector3D in "world": [6.12644e-14, 595.859, -2240.34]
# p̈ref = FreeVector3D in "world": [6.60577e-15, 143.665, -280.897]
# p̈ref = FreeVector3D in "world": [-2.05168e-14, -335.065, 16.6862]
# p̈ref = FreeVector3D in "world": [6.70892e-14, 496.677, -1945.98]
# p̈ref = FreeVector3D in "world": [2.68618e-14, 300.365, -480.476]
# p̈ref = FreeVector3D in "world": [-4.46872e-14, -729.797, -280.117]
# p̈ref = FreeVector3D in "world": [5.50819e-14, 279.602, -1232.38]
# p̈ref = FreeVector3D in "world": [5.14685e-14, 711.581, -1004.92]
# p̈ref = FreeVector3D in "world": [-3.05567e-14, -499.028, -171.992]
# p̈ref = FreeVector3D in "world": [8.04568e-14, 417.585, -1734.75]
# p̈ref = FreeVector3D in "world": [4.02673e-14, 271.672, -418.833]
# p̈ref = FreeVector3D in "world": [-3.21754e-14, -525.463, -190.621]
# p̈ref = FreeVector3D in "world": [8.64117e-14, 414.004, -1748.93]
# p̈ref = FreeVector3D in "world": [3.84709e-14, 190.129, -308.133]
# p̈ref = FreeVector3D in "world": [-3.55788e-14, -581.047, -220.761]
# p̈ref = FreeVector3D in "world": [9.7512e-14, 429.372, -1835.48]
# p̈ref = FreeVector3D in "world": [3.51996e-14, 40.9004, -117.059]
# p̈ref = FreeVector3D in "world": [-4.05961e-14, -662.985, -320.335]
# p̈ref = FreeVector3D in "world": [1.16594e-13, 465.739, -2007.35]
# p̈ref = FreeVector3D in "world": [3.40864e-14, -101.421, 63.8577]
# p̈ref = FreeVector3D in "world": [-5.61539e-14, -917.063, -469.833]
# p̈ref = FreeVector3D in "world": [8.46143e-14, 234.118, -1146.19]
# p̈ref = FreeVector3D in "world": [3.71238e-14, 173.969, -262.471]
# p̈ref = FreeVector3D in "world": [-8.58537e-14, -1402.1, -728.909]
# p̈ref = FreeVector3D in "world": [6.07716e-14, 45.7151, -439.3]
# p̈ref = FreeVector3D in "world": [4.54192e-14, 547.695, -699.485]
# p̈ref = FreeVector3D in "world": [-8.4938e-14, -1387.14, -714.202]
# p̈ref = FreeVector3D in "world": [6.94501e-14, 68.7096, -541.029]
# p̈ref = FreeVector3D in "world": [4.01975e-14, 447.561, -572.233]
# p̈ref = FreeVector3D in "world": [-8.01112e-14, -1308.32, -667.469]
# p̈ref = FreeVector3D in "world": [8.13057e-14, 113.691, -730.581]
# p̈ref = FreeVector3D in "world": [3.37214e-14, 314.008, -410.519]
# p̈ref = FreeVector3D in "world": [-7.42437e-14, -1212.49, -641.903]
# p̈ref = FreeVector3D in "world": [1.02141e-13, 170.28, -978.369]
# p̈ref = FreeVector3D in "world": [1.65385e-14, -107.162, 70.5199]
# p̈ref = FreeVector3D in "world": [-6.03027e-14, -984.817, -524.91]
# p̈ref = FreeVector3D in "world": [1.29665e-13, 312.508, -1554.17]
# p̈ref = FreeVector3D in "world": [1.79132e-14, -100.587, 67.2208]
# p̈ref = FreeVector3D in "world": [-4.27422e-14, -698.033, -406.868]
# p̈ref = FreeVector3D in "world": [1.5841e-13, 457.711, -2124.18]
# p̈ref = FreeVector3D in "world": [2.0964e-14, -97.5143, 65.5869]
# p̈ref = FreeVector3D in "world": [-3.64496e-14, -595.266, -359.685]
# p̈ref = FreeVector3D in "world": [1.78817e-13, 611.838, -2404.5]
# p̈ref = FreeVector3D in "world": [2.13857e-14, -95.3498, 66.794]
# p̈ref = FreeVector3D in "world": [-3.52249e-14, -575.266, -344.863]
# p̈ref = FreeVector3D in "world": [1.91826e-13, 642.172, -2521.85]
# p̈ref = FreeVector3D in "world": [1.99978e-14, -93.6555, 68.2063]
# p̈ref = FreeVector3D in "world": [-3.44298e-14, -562.282, -353.133]
# p̈ref = FreeVector3D in "world": [2.01567e-13, 652.133, -2557.19]
# p̈ref = FreeVector3D in "world": [1.807e-14, -93.2335, 69.9117]
# p̈ref = FreeVector3D in "world": [-3.36221e-14, -549.091, -359.889]
# p̈ref = FreeVector3D in "world": [2.17498e-13, 686.433, -2683.86]
# p̈ref = FreeVector3D in "world": [1.66261e-14, -92.5645, 73.9459]
# p̈ref = FreeVector3D in "world": [-3.78839e-14, -618.691, -497.074]
# p̈ref = FreeVector3D in "world": [2.14275e-13, 451.079, -2198.5]
# p̈ref = FreeVector3D in "world": [1.7986e-14, -97.2232, 73.0007]
# p̈ref = FreeVector3D in "world": [-7.87227e-14, -1285.64, -1107.43]
# p̈ref = FreeVector3D in "world": [1.96625e-13, -29.0904, -201.609]
# p̈ref = FreeVector3D in "world": [3.04724e-14, -126.586, 39.2324]
# p̈ref = FreeVector3D in "world": [-6.9872e-14, -1141.1, -1037.34]
# p̈ref = FreeVector3D in "world": [1.87551e-13, -37.4247, -203.051]
# p̈ref = FreeVector3D in "world": [2.49717e-14, -126.654, 37.1577]
# p̈ref = FreeVector3D in "world": [-6.35824e-14, -1038.38, -1009.39]
# p̈ref = FreeVector3D in "world": [1.79828e-13, -37.8728, -197.199]
# p̈ref = FreeVector3D in "world": [1.97025e-14, -127.085, 37.042]
# p̈ref = FreeVector3D in "world": [-5.90857e-14, -964.943, -1008.1]
# p̈ref = FreeVector3D in "world": [1.71679e-13, -38.2244, -190.405]
# p̈ref = FreeVector3D in "world": [1.35843e-14, -128.036, 39.2003]
# p̈ref = FreeVector3D in "world": [-5.86011e-14, -957.028, -1128.04]
# p̈ref = FreeVector3D in "world": [1.7431e-13, -39.5602, -189.16]
# p̈ref = FreeVector3D in "world": [7.81912e-15, -134.595, 38.889]
# p̈ref = FreeVector3D in "world": [-5.5857e-14, -912.214, -1157.55]
# p̈ref = FreeVector3D in "world": [1.90457e-13, 3.31637, -474.257]
# p̈ref = FreeVector3D in "world": [4.19027e-15, -135.79, 38.0419]
# p̈ref = FreeVector3D in "world": [-4.86325e-14, -794.229, -1091.87]
# p̈ref = FreeVector3D in "world": [2.05188e-13, 73.4765, -942.467]
# p̈ref = FreeVector3D in "world": [1.66829e-16, -134.106, 39.1673]
# p̈ref = FreeVector3D in "world": [-4.13357e-14, -675.063, -992.074]
# p̈ref = FreeVector3D in "world": [1.91702e-13, 77.3097, -983.072]
# p̈ref = FreeVector3D in "world": [-2.67277e-15, -135.234, 32.8314]
# p̈ref = FreeVector3D in "world": [-4.13842e-14, -675.855, -1033.95]
# p̈ref = FreeVector3D in "world": [1.67335e-13, 7.25855, -518.084]
# p̈ref = FreeVector3D in "world": [-4.38325e-15, -142.509, 20.9191]
# p̈ref = FreeVector3D in "world": [-4.73376e-14, -773.082, -1187.23]
# p̈ref = FreeVector3D in "world": [1.64604e-13, -32.5797, -161.034]
# p̈ref = FreeVector3D in "world": [5.10824e-15, -22.3022, -106.795]
# p̈ref = FreeVector3D in "world": [-4.5483e-14, -742.794, -1077.03]
# p̈ref = FreeVector3D in "world": [1.42031e-13, -47.6222, 25.7963]
# p̈ref = FreeVector3D in "world": [4.57926e-15, 30.7687, -53.1134]
# p̈ref = FreeVector3D in "world": [-1.94172e-14, -317.106, -488.215]
# p̈ref = FreeVector3D in "world": [9.92791e-14, 6.69774, -464.183]
# p̈ref = FreeVector3D in "world": [-1.64273e-15, -125.251, 4.75619]
# p̈ref = FreeVector3D in "world": [-1.31248e-14, -214.344, -373.442]
# p̈ref = FreeVector3D in "world": [8.81204e-14, 101.928, -589.458]
# p̈ref = FreeVector3D in "world": [-2.43165e-15, -122.615, 1.8116]
# p̈ref = FreeVector3D in "world": [-1.2671e-14, -206.933, -368.202]
# p̈ref = FreeVector3D in "world": [8.34695e-14, 93.1033, -533.583]
# p̈ref = FreeVector3D in "world": [-1.94235e-15, -124.199, -2.16379]
# p̈ref = FreeVector3D in "world": [-1.02448e-14, -167.31, -268.497]
# p̈ref = FreeVector3D in "world": [7.95413e-14, 21.2158, -628.42]
# p̈ref = FreeVector3D in "world": [5.75523e-15, -37.9337, -63.4993]
# p̈ref = FreeVector3D in "world": [-1.09568e-14, -178.938, -302.653]
# p̈ref = FreeVector3D in "world": [8.28399e-14, 17.2734, -614.37]
# p̈ref = FreeVector3D in "world": [6.45174e-16, -120.645, -6.24958]
# p̈ref = FreeVector3D in "world": [-1.19527e-14, -195.202, -364.493]
# p̈ref = FreeVector3D in "world": [8.21727e-14, 84.199, -514.392]
# p̈ref = FreeVector3D in "world": [6.54443e-17, -126.638, -9.74594]
# p̈ref = FreeVector3D in "world": [-1.07836e-14, -176.11, -301.094]
# p̈ref = FreeVector3D in "world": [8.20649e-14, 87.1502, -566.007]
# p̈ref = FreeVector3D in "world": [1.898e-15, -121.809, -11.4046]
# p̈ref = FreeVector3D in "world": [-1.09297e-14, -178.495, -329.604]
# p̈ref = FreeVector3D in "world": [7.70651e-14, 76.3655, -476.186]
# p̈ref = FreeVector3D in "world": [1.80617e-15, -125.303, -14.9021]
# p̈ref = FreeVector3D in "world": [-1.11595e-14, -182.248, -355.141]
# p̈ref = FreeVector3D in "world": [7.5876e-14, 70.7876, -437.075]
# p̈ref = FreeVector3D in "world": [2.02669e-15, -127.947, -17.3911]
# p̈ref = FreeVector3D in "world": [-1.08829e-14, -177.732, -351.321]
# p̈ref = FreeVector3D in "world": [7.47811e-14, 67.9026, -425.701]
# p̈ref = FreeVector3D in "world": [2.77264e-15, -128.13, -19.8371]
# p̈ref = FreeVector3D in "world": [-1.08609e-14, -177.372, -353.277]
# p̈ref = FreeVector3D in "world": [7.55936e-14, 66.1824, -432.725]
# p̈ref = FreeVector3D in "world": [3.65e-15, -128.695, -22.5023]
# p̈ref = FreeVector3D in "world": [-1.11539e-14, -182.157, -362.887]
# p̈ref = FreeVector3D in "world": [7.83988e-14, 65.0483, -457.479]
# p̈ref = FreeVector3D in "world": [4.74538e-15, -130.046, -26.0273]
# p̈ref = FreeVector3D in "world": [-1.04001e-14, -169.847, -294.429]
# p̈ref = FreeVector3D in "world": [7.27206e-14, 15.7823, -429.999]
# p̈ref = FreeVector3D in "world": [7.30496e-15, -125.132, -31.3605]
# p̈ref = FreeVector3D in "world": [-7.75046e-15, -126.575, -133.746]
# p̈ref = FreeVector3D in "world": [6.79504e-14, -7.51535, -682.562]
# p̈ref = FreeVector3D in "world": [1.49619e-14, 40.3672, -105.733]
# p̈ref = FreeVector3D in "world": [4.9321e-16, 8.05473, 72.0013]
# p̈ref = FreeVector3D in "world": [5.68151e-14, 6.51418, -987.3]
# p̈ref = FreeVector3D in "world": [1.09166e-14, 57.5751, -101.835]
# p̈ref = FreeVector3D in "world": [3.31466e-15, 54.1325, 131.299]
# p̈ref = FreeVector3D in "world": [4.54039e-14, -0.444383, -958.006]
# p̈ref = FreeVector3D in "world": [9.1501e-15, 63.6229, -100.12]
# p̈ref = FreeVector3D in "world": [2.6362e-14, 430.524, 2106.27]
# p̈ref = FreeVector3D in "world": [7.30311e-14, 202.535, -2673.75]
# p̈ref = FreeVector3D in "world": [3.10483e-14, 54.8469, -50.3173]
# p̈ref = FreeVector3D in "world": [1.57593e-14, 257.368, 1490.96]
# p̈ref = FreeVector3D in "world": [4.65389e-14, 114.841, -1660.83]
# p̈ref = FreeVector3D in "world": [2.12826e-14, 27.4703, -34.0713]
# p̈ref = FreeVector3D in "world": [1.40656e-14, 229.708, 1314.13]
# p̈ref = FreeVector3D in "world": [1.24389e-14, 101.399, -1576.44]
# p̈ref = FreeVector3D in "world": [8.32311e-14, 1595.56, -616.392]
# p̈ref = FreeVector3D in "world": [1.70949e-14, 279.181, 1089.44]
# p̈ref = FreeVector3D in "world": [2.24382e-14, 36.4546, -2120.63]
# p̈ref = FreeVector3D in "world": [1.03757e-13, 2352.69, -859.841]
# p̈ref = FreeVector3D in "world": [2.13838e-14, 349.224, 1318.69]
# p̈ref = FreeVector3D in "world": [9.16644e-15, 28.7636, -2109.36]
# p̈ref = FreeVector3D in "world": [8.62352e-14, 2171.91, -727.665]
# p̈ref = FreeVector3D in "world": [1.78423e-14, 291.386, 1891.48]
# p̈ref = FreeVector3D in "world": [1.17019e-14, 101.981, -2011.37]
# p̈ref = FreeVector3D in "world": [5.69523e-14, 1423.89, -435.777]
# p̈ref = FreeVector3D in "world": [1.76245e-14, 287.83, 2497.96]
# p̈ref = FreeVector3D in "world": [1.55603e-14, 108.459, -2164.11]
# p̈ref = FreeVector3D in "world": [1.44703e-14, 450.302, -130.193]
# p̈ref = FreeVector3D in "world": [1.38972e-14, 226.958, 2531.84]
# p̈ref = FreeVector3D in "world": [-1.41323e-14, 13.1764, -1961.49]
# p̈ref = FreeVector3D in "world": [8.8896e-15, 689.451, -166.621]
# p̈ref = FreeVector3D in "world": [1.05123e-14, 171.679, 2308.51]
# p̈ref = FreeVector3D in "world": [-5.901e-14, -13.0397, -1306.35]
# p̈ref = FreeVector3D in "world": [1.77598e-14, 1431.79, -225.534]
# p̈ref = FreeVector3D in "world": [6.10769e-15, 99.7461, 2084.9]
# p̈ref = FreeVector3D in "world": [-8.44276e-14, -24.3818, -906.468]
# p̈ref = FreeVector3D in "world": [2.90809e-14, 2129.52, -322.748]
# p̈ref = FreeVector3D in "world": [6.49016e-16, 10.5992, 1889.87]
# p̈ref = FreeVector3D in "world": [-9.42171e-14, -29.0476, -725.312]
# p̈ref = FreeVector3D in "world": [4.19607e-14, 2902.77, -381.036]
# p̈ref = FreeVector3D in "world": [-4.80522e-15, -78.4753, 1551.04]
# p̈ref = FreeVector3D in "world": [-9.43456e-14, -32.6391, -579.565]
# p̈ref = FreeVector3D in "world": [5.22619e-14, 3574.09, -385.484]
# p̈ref = FreeVector3D in "world": [1.08913e-15, 17.7868, 1048.78]
# p̈ref = FreeVector3D in "world": [-7.45505e-14, 95.0545, -2912.2]
# p̈ref = FreeVector3D in "world": [-9.778e-14, 2014.31, -163.422]
# p̈ref = FreeVector3D in "world": [2.11831e-14, 345.946, 318.546]
# p̈ref = FreeVector3D in "world": [-2.57879e-14, 129.645, -3977.39]
# p̈ref = FreeVector3D in "world": [-1.23388e-13, 1917.1, -108.028]
# p̈ref = FreeVector3D in "world": [1.78504e-14, 291.519, 276.571]
# p̈ref = FreeVector3D in "world": [2.47847e-14, 105.269, -3255.83]
# p̈ref = FreeVector3D in "world": [-4.9827e-14, 2206.46, -83.433]
# p̈ref = FreeVector3D in "world": [1.36702e-14, 223.251, 354.763]
# p̈ref = FreeVector3D in "world": [5.66686e-14, 99.3822, -2961.16]
# p̈ref = FreeVector3D in "world": [-2.57579e-14, 1989.94, 48.2182]
# p̈ref = FreeVector3D in "world": [1.68663e-14, 275.447, 475.571]
# p̈ref = FreeVector3D in "world": [1.76846e-14, 82.0351, -2390.33]
# p̈ref = FreeVector3D in "world": [-2.81072e-14, 2304.59, 112.771]
# p̈ref = FreeVector3D in "world": [1.28496e-14, 209.85, 445.652]
# p̈ref = FreeVector3D in "world": [5.30966e-15, 68.6173, -1852.29]
# p̈ref = FreeVector3D in "world": [-1.14736e-14, 2645.4, 188.478]
# p̈ref = FreeVector3D in "world": [3.66165e-15, 59.7992, 267.354]
# p̈ref = FreeVector3D in "world": [2.17716e-14, 60.4217, -1459.72]
# p̈ref = FreeVector3D in "world": [1.57578e-14, 2699.07, 251.062]
# p̈ref = FreeVector3D in "world": [-2.00808e-15, -32.7945, 135.103]
# p̈ref = FreeVector3D in "world": [2.77194e-14, 55.1313, -1129.98]
# p̈ref = FreeVector3D in "world": [3.14126e-14, 2691.49, 309.554]
# p̈ref = FreeVector3D in "world": [-3.22614e-15, -52.6869, 100.698]
# p̈ref = FreeVector3D in "world": [3.00135e-14, 56.1582, -1051.68]
# p̈ref = FreeVector3D in "world": [3.08554e-14, 2567.13, 357.62]
# p̈ref = FreeVector3D in "world": [-5.45695e-15, -89.1188, 60.7157]
# p̈ref = FreeVector3D in "world": [3.66717e-14, 58.7724, -1041.76]
# p̈ref = FreeVector3D in "world": [3.07554e-14, 2415.15, 396.088]
# p̈ref = FreeVector3D in "world": [-5.56808e-14, -909.337, 34.6811]
# p̈ref = FreeVector3D in "world": [1.48361e-14, 51.4691, -635.587]
# p̈ref = FreeVector3D in "world": [1.4369e-14, 1903.65, 370.278]
# p̈ref = FreeVector3D in "world": [-4.32398e-14, -706.159, 18.9246]
# p̈ref = FreeVector3D in "world": [2.94576e-14, 57.0875, -789.269]
# p̈ref = FreeVector3D in "world": [1.87013e-14, 1893.49, 411.482]
# p̈ref = FreeVector3D in "world": [-3.84483e-14, -627.909, 30.8897]
# p̈ref = FreeVector3D in "world": [2.87924e-14, 59.4643, -792.106]
# p̈ref = FreeVector3D in "world": [1.68783e-14, 1924.33, 462.745]
# p̈ref = FreeVector3D in "world": [-3.61225e-14, -589.925, 44.8658]
# p̈ref = FreeVector3D in "world": [2.59077e-14, 61.127, -756.629]
# p̈ref = FreeVector3D in "world": [1.36887e-14, 1899.37, 502.34]
# p̈ref = FreeVector3D in "world": [-3.34643e-14, -546.513, 55.0903]
# p̈ref = FreeVector3D in "world": [2.21313e-14, 62.4443, -706.146]
# p̈ref = FreeVector3D in "world": [1.034e-14, 1868.11, 538.961]
# p̈ref = FreeVector3D in "world": [-2.81262e-14, -459.336, 57.6499]
# p̈ref = FreeVector3D in "world": [1.86413e-14, 63.8133, -660.645]
# p̈ref = FreeVector3D in "world": [7.70821e-15, 1873.01, 584.18]
# p̈ref = FreeVector3D in "world": [-2.71038e-14, -442.638, 46.9742]
# p̈ref = FreeVector3D in "world": [1.38941e-14, 63.6533, -585.645]
# p̈ref = FreeVector3D in "world": [4.92408e-15, 1861.96, 625.235]
# p̈ref = FreeVector3D in "world": [-2.72232e-14, -444.588, 23.2564]
# p̈ref = FreeVector3D in "world": [1.12444e-14, 63.4473, -522.131]
# p̈ref = FreeVector3D in "world": [3.26954e-15, 1836.49, 661.131]
# p̈ref = FreeVector3D in "world": [-2.74725e-14, -448.66, -9.36086]
# p̈ref = FreeVector3D in "world": [1.14959e-14, 63.9159, -482.733]
# p̈ref = FreeVector3D in "world": [2.92419e-15, 1793.2, 689.458]
# p̈ref = FreeVector3D in "world": [-2.5853e-14, -422.211, -40.5507]
# p̈ref = FreeVector3D in "world": [1.39606e-14, 65.6169, -470.367]
# p̈ref = FreeVector3D in "world": [3.34795e-15, 1742.69, 712.747]
# p̈ref = FreeVector3D in "world": [-1.92295e-14, -314.042, -53.7122]
# p̈ref = FreeVector3D in "world": [2.06095e-14, 71.3321, -524.219]
# p̈ref = FreeVector3D in "world": [4.42238e-15, 1686.55, 730.631]
# p̈ref = FreeVector3D in "world": [-2.27315e-14, -371.234, -79.6371]
# p̈ref = FreeVector3D in "world": [2.10078e-14, 70.899, -471.145]
# p̈ref = FreeVector3D in "world": [4.39924e-15, 1555.93, 714.31]
# p̈ref = FreeVector3D in "world": [-2.37394e-14, -387.694, -99.0058]
# p̈ref = FreeVector3D in "world": [2.36134e-14, 72.6553, -455.137]
# p̈ref = FreeVector3D in "world": [4.93329e-15, 1435.96, 696.262]
# p̈ref = FreeVector3D in "world": [-2.40182e-14, -392.246, -115.029]
# p̈ref = FreeVector3D in "world": [2.59662e-14, 74.4707, -440.799]
# p̈ref = FreeVector3D in "world": [5.47374e-15, 1323.74, 675.923]
# p̈ref = FreeVector3D in "world": [-1.86602e-14, -304.744, -99.4122]
# p̈ref = FreeVector3D in "world": [2.62063e-14, 77.8259, -443.447]
# p̈ref = FreeVector3D in "world": [3.91046e-15, 1280.66, 684.792]
# p̈ref = FreeVector3D in "world": [-1.43585e-14, -234.492, -85.2738]
# p̈ref = FreeVector3D in "world": [2.28406e-14, 77.789, -407.741]
# p̈ref = FreeVector3D in "world": [1.29574e-15, 1266.76, 707.326]
# ...
# p̈ref = FreeVector3D in "world": [3.45519e-15, 56.4276, -28.4124]
# p̈ref = FreeVector3D in "world": [1.88478e-14, 82.0724, 63.0591]
# p̈ref = FreeVector3D in "world": [7.11466e-15, 59.995, -7.38731]
# p̈ref = FreeVector3D in "world": [1.18774e-14, 193.973, -5.67365]
# p̈ref = FreeVector3D in "world": [1.29878e-14, -90.478, -61.0971]
# p̈ref = FreeVector3D in "world": [1.11634e-14, 114.367, 93.0468]
# p̈ref = FreeVector3D in "world": [1.10183e-14, 179.942, 0.117553]
# p̈ref = FreeVector3D in "world": [1.1864e-14, -90.1376, -58.7866]
# p̈ref = FreeVector3D in "world": [1.1412e-14, 111.793, 93.2809]
# p̈ref = FreeVector3D in "world": [1.00807e-14, 164.631, 0.505756]
# p̈ref = FreeVector3D in "world": [7.45549e-15, -110.03, 12.9127]
# p̈ref = FreeVector3D in "world": [1.14989e-14, 108.669, 92.855]
# p̈ref = FreeVector3D in "world": [8.49342e-15, 138.708, 8.62161]
# p̈ref = FreeVector3D in "world": [4.9875e-15, -109.264, 11.0887]
# p̈ref = FreeVector3D in "world": [1.18028e-14, 105.684, 92.2841]
# p̈ref = FreeVector3D in "world": [1.59753e-14, 260.896, -16.8104]
# p̈ref = FreeVector3D in "world": [4.29551e-14, 73.7036, 71.977]
# p̈ref = FreeVector3D in "world": [5.40936e-15, 54.0872, -29.4004]
# p̈ref = FreeVector3D in "world": [1.95964e-14, 320.033, -51.5491]
# p̈ref = FreeVector3D in "world": [4.73184e-14, 71.8625, 73.1462]
# p̈ref = FreeVector3D in "world": [-1.17363e-15, 10.8587, -119.001]
# p̈ref = FreeVector3D in "world": [1.96387e-14, 320.724, -49.2469]
# p̈ref = FreeVector3D in "world": [4.77978e-14, 73.002, 74.0114]
# p̈ref = FreeVector3D in "world": [-2.43525e-15, 4.0319, -118.745]
# p̈ref = FreeVector3D in "world": [1.97304e-14, 322.221, -46.7427]
# p̈ref = FreeVector3D in "world": [4.8135e-14, 73.1599, 74.914]
# p̈ref = FreeVector3D in "world": [-3.30546e-15, -0.523975, -118.774]
# p̈ref = FreeVector3D in "world": [1.98107e-14, 323.534, -44.2987]
# p̈ref = FreeVector3D in "world": [4.81851e-14, 72.0457, 75.7679]
# p̈ref = FreeVector3D in "world": [-3.71309e-15, -1.81663, -118.879]
# p̈ref = FreeVector3D in "world": [1.98469e-14, 324.125, -42.6391]
# p̈ref = FreeVector3D in "world": [4.79579e-14, 69.9707, 76.6301]
# p̈ref = FreeVector3D in "world": [-3.6894e-15, -0.251006, -118.845]
# p̈ref = FreeVector3D in "world": [1.99813e-14, 326.319, -41.0706]
# p̈ref = FreeVector3D in "world": [4.79788e-14, 68.6336, 77.5745]
# p̈ref = FreeVector3D in "world": [-3.74818e-15, 0.899362, -118.662]
# p̈ref = FreeVector3D in "world": [1.96826e-14, 321.441, -40.0639]
# p̈ref = FreeVector3D in "world": [4.78152e-14, 69.014, 78.699]
# p̈ref = FreeVector3D in "world": [-4.34084e-15, -2.62155, -119.275]
# p̈ref = FreeVector3D in "world": [1.96239e-14, 320.483, -38.4994]
# p̈ref = FreeVector3D in "world": [4.75527e-14, 67.1424, 79.7086]
# p̈ref = FreeVector3D in "world": [-4.43823e-15, -1.79012, -119.388]
# p̈ref = FreeVector3D in "world": [1.95722e-14, 319.638, -36.8655]
# p̈ref = FreeVector3D in "world": [4.7288e-14, 65.4395, 80.6566]
# p̈ref = FreeVector3D in "world": [-4.52113e-15, -0.966703, -119.468]
# p̈ref = FreeVector3D in "world": [1.95342e-14, 319.018, -35.2396]
# p̈ref = FreeVector3D in "world": [4.70504e-14, 63.8668, 81.57]
# p̈ref = FreeVector3D in "world": [-4.61017e-15, -0.291512, -119.542]
# p̈ref = FreeVector3D in "world": [1.95333e-14, 319.002, -33.5283]
# p̈ref = FreeVector3D in "world": [4.68584e-14, 62.3295, 82.4505]
# p̈ref = FreeVector3D in "world": [-4.70489e-15, 0.324479, -119.585]
# p̈ref = FreeVector3D in "world": [1.95864e-14, 319.87, -31.7484]
# p̈ref = FreeVector3D in "world": [4.67108e-14, 60.7057, 83.2963]
# p̈ref = FreeVector3D in "world": [-4.76557e-15, 1.17536, -119.537]
# p̈ref = FreeVector3D in "world": [1.96359e-14, 320.679, -30.1905]
# p̈ref = FreeVector3D in "world": [4.64594e-14, 58.9425, 83.9902]
# p̈ref = FreeVector3D in "world": [-4.61722e-15, 3.23981, -119.297]
# p̈ref = FreeVector3D in "world": [1.94713e-14, 317.991, -29.489]
# p̈ref = FreeVector3D in "world": [4.59562e-14, 57.8456, 84.4599]
# p̈ref = FreeVector3D in "world": [-4.33527e-15, 5.35629, -119.248]
# p̈ref = FreeVector3D in "world": [1.92621e-14, 314.573, -28.8918]
# p̈ref = FreeVector3D in "world": [4.56293e-14, 57.3671, 85.0547]
# p̈ref = FreeVector3D in "world": [-4.33772e-15, 5.51993, -119.468]
# p̈ref = FreeVector3D in "world": [1.92177e-14, 313.849, -27.6143]
# p̈ref = FreeVector3D in "world": [4.5421e-14, 56.6737, 85.6047]
# p̈ref = FreeVector3D in "world": [-4.30209e-15, 6.41211, -119.449]
# p̈ref = FreeVector3D in "world": [1.92043e-14, 313.631, -26.3644]
# p̈ref = FreeVector3D in "world": [4.53327e-14, 56.1892, 86.2324]
# p̈ref = FreeVector3D in "world": [-4.30552e-15, 7.16951, -119.378]
# p̈ref = FreeVector3D in "world": [1.91167e-14, 312.199, -25.6424]
# p̈ref = FreeVector3D in "world": [4.48612e-14, 54.4414, 86.844]
# p̈ref = FreeVector3D in "world": [-3.94638e-15, 9.47904, -119.116]
# p̈ref = FreeVector3D in "world": [1.90551e-14, 311.194, -24.657]
# p̈ref = FreeVector3D in "world": [4.46938e-14, 53.9029, 87.4281]
# p̈ref = FreeVector3D in "world": [-3.88258e-15, 10.2535, -119.081]
# p̈ref = FreeVector3D in "world": [1.86386e-14, 304.391, -24.231]
# p̈ref = FreeVector3D in "world": [4.38593e-14, 53.5197, 87.8692]
# p̈ref = FreeVector3D in "world": [-3.80363e-15, 10.6766, -119.284]
# p̈ref = FreeVector3D in "world": [1.9621e-14, 320.435, -34.5028]
# p̈ref = FreeVector3D in "world": [4.66153e-14, 52.4166, 89.4244]
# p̈ref = FreeVector3D in "world": [-3.80307e-15, 11.0858, -118.851]
# p̈ref = FreeVector3D in "world": [3.104e-14, 506.922, -193.419]
# p̈ref = FreeVector3D in "world": [6.00647e-14, 41.405, 92.6167]
# p̈ref = FreeVector3D in "world": [-8.11219e-15, 10.123, -119.566]
# p̈ref = FreeVector3D in "world": [3.01497e-14, 492.382, -219.957]
# p̈ref = FreeVector3D in "world": [5.71215e-14, 40.0419, 92.483]
# p̈ref = FreeVector3D in "world": [-8.21968e-15, 9.5676, -121.058]
# p̈ref = FreeVector3D in "world": [3.09396e-14, 505.283, -246.457]
# p̈ref = FreeVector3D in "world": [5.70707e-14, 37.7047, 92.9315]
# p̈ref = FreeVector3D in "world": [-8.67482e-15, 9.58622, -121.614]
# p̈ref = FreeVector3D in "world": [3.19274e-14, 521.415, -270.149]
# p̈ref = FreeVector3D in "world": [5.73811e-14, 35.2939, 93.3867]
# p̈ref = FreeVector3D in "world": [-9.16398e-15, 9.69576, -121.959]
# p̈ref = FreeVector3D in "world": [3.26085e-14, 532.537, -292.012]
# p̈ref = FreeVector3D in "world": [5.70722e-14, 33.0159, 93.593]
# p̈ref = FreeVector3D in "world": [-9.59424e-15, 9.75065, -122.403]
# p̈ref = FreeVector3D in "world": [3.18929e-14, 520.851, -300.039]
# p̈ref = FreeVector3D in "world": [5.46635e-14, 31.9195, 93.2667]
# p̈ref = FreeVector3D in "world": [-9.60525e-15, 9.89983, -122.998]
# p̈ref = FreeVector3D in "world": [2.85027e-14, 465.485, -247.743]
# p̈ref = FreeVector3D in "world": [5.00014e-14, 34.9898, 92.5917]
# p̈ref = FreeVector3D in "world": [-8.58025e-15, 10.733, -122.709]
# p̈ref = FreeVector3D in "world": [2.73003e-14, 445.847, -166.549]
# p̈ref = FreeVector3D in "world": [5.03649e-14, 37.2241, 92.8843]
# p̈ref = FreeVector3D in "world": [-7.94018e-15, 12.1544, -120.568]
# p̈ref = FreeVector3D in "world": [2.43259e-14, 397.272, -83.7638]
# p̈ref = FreeVector3D in "world": [4.84814e-14, 39.4195, 92.7229]
# p̈ref = FreeVector3D in "world": [-6.606e-15, 13.6226, -118.875]
# p̈ref = FreeVector3D in "world": [2.09128e-14, 341.532, -46.2429]
# p̈ref = FreeVector3D in "world": [4.37987e-14, 47.8793, 85.6656]
# p̈ref = FreeVector3D in "world": [-5.86627e-15, 13.4686, -118.881]
# p̈ref = FreeVector3D in "world": [6.38625e-14, 1042.95, -39.0302]
# p̈ref = FreeVector3D in "world": [1.03053e-13, -118.404, -19.8121]
# p̈ref = FreeVector3D in "world": [-6.19666e-15, 81.794, 112.995]
# p̈ref = FreeVector3D in "world": [1.24986e-13, 2041.18, -71.6357]
# p̈ref = FreeVector3D in "world": [2.08912e-13, -164.791, -60.5332]
# p̈ref = FreeVector3D in "world": [-1.76824e-14, 62.6884, 192.916]
# p̈ref = FreeVector3D in "world": [1.33317e-13, 2177.24, -799.937]
# p̈ref = FreeVector3D in "world": [1.95091e-13, -215.603, -83.3183]
# p̈ref = FreeVector3D in "world": [-3.4598e-14, -1.85887, 143.956]
# p̈ref = FreeVector3D in "world": [1.3567e-13, 2215.66, -1158.43]
# p̈ref = FreeVector3D in "world": [1.95677e-13, -242.315, -93.807]
# p̈ref = FreeVector3D in "world": [-3.97703e-14, -27.0146, 124.818]
# p̈ref = FreeVector3D in "world": [1.02421e-13, 1672.66, -882.405]
# p̈ref = FreeVector3D in "world": [1.62506e-13, -162.17, -90.9444]
# p̈ref = FreeVector3D in "world": [-2.90407e-14, -24.2211, 117.666]
# p̈ref = FreeVector3D in "world": [4.96955e-14, 811.589, -573.268]
# p̈ref = FreeVector3D in "world": [1.0601e-13, 63.8065, 25.4725]
# p̈ref = FreeVector3D in "world": [-1.11821e-14, 5.52773, -119.81]
# p̈ref = FreeVector3D in "world": [7.88602e-15, 128.788, -389.07]
# p̈ref = FreeVector3D in "world": [2.67386e-14, 48.7529, 83.5986]
# p̈ref = FreeVector3D in "world": [1.33589e-15, 10.8134, -127.815]
# p̈ref = FreeVector3D in "world": [1.65415e-14, 270.143, 27.7676]
# p̈ref = FreeVector3D in "world": [5.88309e-14, 149.192, 163.054]
# p̈ref = FreeVector3D in "world": [-5.00732e-15, 6.94133, -121.891]
# p̈ref = FreeVector3D in "world": [2.24946e-14, 367.365, 39.7636]
# p̈ref = FreeVector3D in "world": [1.24009e-13, 516.539, 468.238]
# p̈ref = FreeVector3D in "world": [-8.13696e-15, -6.3765, -128.845]
# p̈ref = FreeVector3D in "world": [2.51596e-14, 410.888, 54.2956]
# p̈ref = FreeVector3D in "world": [1.35807e-13, 562.902, 512.991]
# p̈ref = FreeVector3D in "world": [-1.10808e-14, -13.3332, -133.345]
# p̈ref = FreeVector3D in "world": [2.4945e-14, 407.382, 61.5189]
# p̈ref = FreeVector3D in "world": [1.42537e-13, 599.408, 549.3]
# p̈ref = FreeVector3D in "world": [-1.23137e-14, -16.3597, -136.245]
# p̈ref = FreeVector3D in "world": [2.34345e-14, 382.714, 63.6859]
# p̈ref = FreeVector3D in "world": [1.27082e-13, 506.938, 475.769]
# p̈ref = FreeVector3D in "world": [-1.29992e-14, -15.7326, -136.641]
# p̈ref = FreeVector3D in "world": [2.16565e-14, 353.678, 63.9992]
# p̈ref = FreeVector3D in "world": [9.89047e-14, 339.854, 336.905]
# p̈ref = FreeVector3D in "world": [-1.35044e-14, -13.3815, -135.02]
# p̈ref = FreeVector3D in "world": [2.04363e-14, 333.75, 65.5377]
# p̈ref = FreeVector3D in "world": [7.74211e-14, 212.954, 230.672]
# p̈ref = FreeVector3D in "world": [-1.40851e-14, -11.9245, -133.54]
# p̈ref = FreeVector3D in "world": [2.20863e-14, 360.697, 77.4772]
# p̈ref = FreeVector3D in "world": [9.5546e-14, 308.923, 318.138]
# p̈ref = FreeVector3D in "world": [-1.63941e-14, -16.5942, -136.679]
# p̈ref = FreeVector3D in "world": [2.20285e-14, 359.752, 83.427]
# p̈ref = FreeVector3D in "world": [9.28298e-14, 288.526, 304.346]
# p̈ref = FreeVector3D in "world": [-1.77385e-14, -17.9704, -137.309]
# p̈ref = FreeVector3D in "world": [2.06639e-14, 337.467, 83.5678]
# p̈ref = FreeVector3D in "world": [7.24552e-14, 171.411, 202.782]
# p̈ref = FreeVector3D in "world": [-1.80121e-14, -16.3676, -135.311]
# p̈ref = FreeVector3D in "world": [1.98801e-14, 324.666, 85.5765]
# p̈ref = FreeVector3D in "world": [6.22177e-14, 113.179, 152.355]
# p̈ref = FreeVector3D in "world": [-1.85331e-14, -16.0491, -134.244]
# p̈ref = FreeVector3D in "world": [1.93903e-14, 316.668, 88.5657]
# p̈ref = FreeVector3D in "world": [5.71686e-14, 84.8258, 128.039]
# p̈ref = FreeVector3D in "world": [-1.91904e-14, -16.2862, -133.552]
# p̈ref = FreeVector3D in "world": [1.88517e-14, 307.872, 91.1006]
# p̈ref = FreeVector3D in "world": [5.18517e-14, 55.5665, 102.259]
# p̈ref = FreeVector3D in "world": [-1.97209e-14, -16.392, -132.692]
# p̈ref = FreeVector3D in "world": [1.84577e-14, 301.437, 94.2836]
# p̈ref = FreeVector3D in "world": [4.90169e-14, 40.4913, 89.473]
# p̈ref = FreeVector3D in "world": [-2.03229e-14, -16.4025, -131.696]
# p̈ref = FreeVector3D in "world": [1.81959e-14, 297.161, 98.0139]
# p̈ref = FreeVector3D in "world": [4.85168e-14, 38.7511, 89.3239]
# p̈ref = FreeVector3D in "world": [-2.09746e-14, -16.3097, -130.6]
# p̈ref = FreeVector3D in "world": [1.92032e-14, 313.612, 108.702]
# p̈ref = FreeVector3D in "world": [6.74146e-14, 146.226, 185.347]
# p̈ref = FreeVector3D in "world": [-2.28858e-14, -17.0497, -130.137]
# p̈ref = FreeVector3D in "world": [1.85135e-14, 302.348, 109.191]
# p̈ref = FreeVector3D in "world": [6.22638e-14, 121.026, 161.321]
# p̈ref = FreeVector3D in "world": [-2.28674e-14, -16.3426, -128.602]
# p̈ref = FreeVector3D in "world": [1.80426e-14, 294.659, 110.135]
# p̈ref = FreeVector3D in "world": [5.96221e-14, 108.648, 150.03]
# p̈ref = FreeVector3D in "world": [-2.30184e-14, -16.3341, -127.836]
# p̈ref = FreeVector3D in "world": [1.72559e-14, 281.811, 108.711]
# p̈ref = FreeVector3D in "world": [5.17077e-14, 68.0598, 110.975]
# p̈ref = FreeVector3D in "world": [-2.26214e-14, -14.8343, -125.688]
# p̈ref = FreeVector3D in "world": [1.54295e-14, 251.982, 96.9957]
# p̈ref = FreeVector3D in "world": [4.5561e-14, 56.5592, 99.019]
# p̈ref = FreeVector3D in "world": [-2.07571e-14, -12.5499, -123.222]
# p̈ref = FreeVector3D in "world": [1.29667e-14, 211.762, 78.6715]
# p̈ref = FreeVector3D in "world": [5.02436e-14, 123.644, 160.318]
# p̈ref = FreeVector3D in "world": [-1.80998e-14, -11.0708, -121.734]
# p̈ref = FreeVector3D in "world": [1.64239e-14, 268.223, 108.52]
# p̈ref = FreeVector3D in "world": [4.59108e-14, 42.9926, 85.5005]
# p̈ref = FreeVector3D in "world": [-2.23124e-14, -11.7221, -121.4]
# p̈ref = FreeVector3D in "world": [1.61142e-14, 263.164, 107.992]
# p̈ref = FreeVector3D in "world": [4.65087e-14, 49.7392, 91.0038]
# p̈ref = FreeVector3D in "world": [-2.20967e-14, -11.0205, -120.49]
# p̈ref = FreeVector3D in "world": [1.57988e-14, 258.013, 107.278]
# p̈ref = FreeVector3D in "world": [4.86805e-14, 66.0968, 105.172]
# p̈ref = FreeVector3D in "world": [-2.18181e-14, -10.2435, -119.583]
# p̈ref = FreeVector3D in "world": [1.52972e-14, 249.822, 105.221]
# p̈ref = FreeVector3D in "world": [5.01947e-14, 80.0313, 116.87]
# p̈ref = FreeVector3D in "world": [-2.12751e-14, -9.35743, -118.674]
# p̈ref = FreeVector3D in "world": [1.09348e-14, 178.579, 77.3343]
# p̈ref = FreeVector3D in "world": [5.77736e-14, 184.124, 208.57]
# p̈ref = FreeVector3D in "world": [-1.63864e-14, -8.07587, -117.761]
# p̈ref = FreeVector3D in "world": [-5.59485e-15, -91.3708, -665.511]
# p̈ref = FreeVector3D in "world": [9.39078e-14, 844.521, 803.635]
# p̈ref = FreeVector3D in "world": [2.25716e-14, 12.5003, -99.3459]
# p̈ref = FreeVector3D in "world": [-1.32748e-14, -216.794, -1082.8]
# p̈ref = FreeVector3D in "world": [1.11031e-13, 1196.89, 1126.7]
# p̈ref = FreeVector3D in "world": [4.67264e-14, 39.8138, -75.576]
# p̈ref = FreeVector3D in "world": [-3.74663e-15, -61.187, -774.316]
# p̈ref = FreeVector3D in "world": [9.17781e-14, 878.913, 826.727]
# p̈ref = FreeVector3D in "world": [2.52154e-14, 18.2227, -93.7642]
# p̈ref = FreeVector3D in "world": [5.57614e-15, 91.0653, -364.543]
# p̈ref = FreeVector3D in "world": [6.35836e-14, 453.873, 440.435]
# p̈ref = FreeVector3D in "world": [1.64887e-15, -0.869013, -110.366]
# p̈ref = FreeVector3D in "world": [1.43094e-14, 233.69, 100.453]
# p̈ref = FreeVector3D in "world": [4.25785e-14, 48.4092, 85.6182]
# p̈ref = FreeVector3D in "world": [-1.99292e-14, -5.43496, -115.867]
# p̈ref = FreeVector3D in "world": [1.56268e-14, 255.205, 112.322]
# p̈ref = FreeVector3D in "world": [4.47085e-14, 47.8519, 84.7913]
# p̈ref = FreeVector3D in "world": [-2.09137e-14, -2.78833, -114.377]
# p̈ref = FreeVector3D in "world": [1.60208e-14, 261.64, 110.096]
# p̈ref = FreeVector3D in "world": [4.51292e-14, 48.072, 84.2793]
# p̈ref = FreeVector3D in "world": [-2.06815e-14, -0.553909, -113.337]
# p̈ref = FreeVector3D in "world": [1.52936e-14, 249.764, 104.54]
# p̈ref = FreeVector3D in "world": [4.41466e-14, 49.0654, 84.1742]
# p̈ref = FreeVector3D in "world": [-1.94929e-14, 0.819383, -112.943]
# true
# p̈ref = FreeVector3D in "world": [1.56818e-14, 256.103, 107.447]
# p̈ref = FreeVector3D in "world": [4.78613e-14, 69.1849, 99.462]
# p̈ref = FreeVector3D in "world": [-1.98273e-14, 1.22622, -112.98]
# p̈ref = FreeVector3D in "world": [1.59769e-14, 260.923, 110.339]
# p̈ref = FreeVector3D in "world": [5.72513e-14, 125.591, 144.176]
# p̈ref = FreeVector3D in "world": [-2.04787e-14, -0.172689, -113.605]
# INFO: ws|server received OPCODE_PING
# INFO: ws|server received OPCODE_PING
# INFO: ws|server received OPCODE_PING
# INFO: ws|server received OPCODE_PING
# INFO: ws|server received OPCODE_PING

# %%
using Blink

# %%
body!(Window(), manipulate!(mvis_full))
# Out:
# Blink.Page(2, WebSockets.WebSocket{TCPSocket}(TCPSocket(RawFD(57) active, 0 bytes waiting), true, CONNECTED::WebSockets.ReadyState = 1), Dict{String,Any}(Pair{String,Any}("webio", WebIO.#111),Pair{String,Any}("callback", Blink.#1)), Future(1, 1, 2, Nullable{Any}(true)))
# WARNING: both Blink and RigidBodyDynamics export "id"; uses of it in module Main must be qualified
# WARNING: both SimpleQP and RigidBodySim export "solve!"; uses of it in module Main must be qualified
# WARNING: both Gurobi and LCPSim export "optimize"; uses of it in module Main must be qualified
# WARNING: both LearningMPC and QPControl export "MPCController"; uses of it in module Main must be qualified
# WARNING: both LCPSim and RigidBodyDynamics export "simulate"; uses of it in module Main must be qualified
# WARNING: both QPControl and Contact export "ContactPoint"; uses of it in module Main must be qualified
