# %%
sum((x -> get(x.inertia).mass).(findbody.(atlas, [
                "pelvis",
                "ltorso",
                "mtorso",
                "utorso",
                "head",
                "l_clav",
                "r_clav",
                "l_uglut",
                "r_uglut"
                ])))

m = sum((x -> get(x.inertia).mass).(findbody.(atlas, [
                "l_scap",
                "l_uarm",
                ])))

r = 0.1
l = 0.4
1/12 * m * (3r^2 + l^2)

1/2 * m * r^2

m = sum((x -> get(x.inertia).mass).(findbody.(atlas, [
                "l_larm",
                "l_ufarm",
                "l_lfarm",
                "l_hand",
                "l_hand_mount"
                ])))

r = 0.1
l = 0.4
1/12 * m * (3r^2 + l^2), 1/2 * m * r^2

m = sum((x -> get(x.inertia).mass).(findbody.(atlas, [
                "l_lglut",
                "l_uleg"
                ])))

r = 0.1
l = 0.475
1/12 * m * (3r^2 + l^2), 1/2 * m * r^2

m = sum((x -> get(x.inertia).mass).(findbody.(atlas, [
                "l_lleg",
                "l_talus",
                "l_foot",
                "l_foot_sole"
                ])))

r = 0.1
l = 0.475
1/12 * m * (3r^2 + l^2), 1/2 * m * r^2
