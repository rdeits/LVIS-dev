# %%
using Revise

# %%
using RigidBodyDynamics
using DrakeVisualizer
DrakeVisualizer.any_open_windows() || DrakeVisualizer.new_window()
using RigidBodyTreeInspector
using Gurobi
import StochasticOptimization
using Plots; gr()
using JLD2
using ProgressMeter

# %%
import LCPSim
import LearningMPC
import CartPoles
import Nets

# %%
robot = CartPoles.CartPole(false)
mechanism = robot.mechanism
xstar = CartPoles.nominal_state(robot)

basevis = Visualizer()[:cartpole]
setgeometry!(basevis, robot)
settransform!(basevis[:robot], xstar)

mpc_params = LearningMPC.MPCParams(
    Δt=0.05,
    horizon=10,
    mip_solver=GurobiSolver(Gurobi.Env(), OutputFlag=0, TimeLimit=120, MIPGap=1e-1, FeasibilityTol=1e-3),
    lcp_solver=GurobiSolver(Gurobi.Env(), OutputFlag=0))

Q, R = CartPoles.default_costs(robot)
lqrsol = LearningMPC.LQRSolution(xstar, Q, R, mpc_params.Δt)

hidden_widths = [16, 16, 16]
activation = Nets.leaky_relu
net = LearningMPC.control_net(mechanism, hidden_widths, activation)

net_controller = x -> Nets.predict(net, state_vector(x))

mpc_controller = LearningMPC.MPCController(mechanism, 
    robot.environment, mpc_params, lqrsol, 
    [net_controller, lqrsol]);

sample_sink = LearningMPC.MPCSampleSink{Float64}()
playback_sink = LearningMPC.PlaybackSink(basevis[:robot], mpc_params.Δt)

mpc_controller.callback = LearningMPC.call_each(
    sample_sink,
    playback_sink)

live_viewer = LearningMPC.live_viewer(mechanism, basevis[:robot])

dagger_controller = LearningMPC.call_each(
    LearningMPC.dagger_controller(
        mpc_controller,
        net_controller,
        0.2),
    live_viewer
    )

termination = x -> begin
    (configuration(x)[2] < -π/2 ||
     configuration(x)[2] > π/2)
end

dataset = LearningMPC.Dataset(lqrsol)

updater = Nets.adam_updater(net)

gradient_sensitivity = 0.8
loss = LearningMPC.sensitive_loss(net, gradient_sensitivity)
adam_opts = Nets.AdamOpts(learning_rate=1e-3, batch_size=1)

function collect_into!(data::Vector{<:LearningMPC.Sample})
    empty!(sample_sink)
    LearningMPC.randomize!(x0, xstar, 0.1, 0.5)
    results = LCPSim.simulate(x0, 
        dagger_controller,
        robot.environment, mpc_params.Δt, 100, 
        mpc_params.lcp_solver;
        termination=termination);
    append!(data, sample_sink.samples)
end

all_losses(net, dataset) = (LearningMPC.training_loss(net, dataset),
                            LearningMPC.validation_loss(net, dataset))

x0 = MechanismState{Float64}(mechanism)

# %%
losses = Tuple{Float64, Float64}[]
snapshots = LearningMPC.Snapshot{Float64}[]

@showprogress for i in 1:15
    for i in 1:2
        collect_into!(dataset.training_data)
    end
    collect_into!(dataset.testing_data)
    collect_into!(dataset.validation_data);
    
    for i in 1:5
        Nets.adam_update!(net.params.data, updater, loss, 
            LearningMPC.features.(dataset.training_data), adam_opts);
        push!(losses, all_losses(net, dataset))
    end
    
    push!(snapshots, LearningMPC.Snapshot(net.params.data, net))
    
    jldopen("cart-pole.jld2", "w") do file
        file["dataset"] = dataset
        file["snapshots"] = snapshots
    end
    
    plt = plot(first.(losses), label="training")
    plot!(plt, last.(losses), label="validation")
    ylims!(plt, (0, ylims(plt)[2]))
    display(plt)
end

# %%
basename = "cart-pole-losses-sensitivity-$gradient_sensitivity"

# %%
jldopen("$basename.jld2", "w") do file
    file["losses"] = losses
end;

plt = plot(first.(losses), label="training", ylim=(0, max(maximum(first, losses), maximum(last, losses))))
plot!(plt, last.(losses), label="validation")
savefig(plt, "$basename.pdf")
savefig(plt, "$basename.png")
plt

# %%
plt = plot()

for sensitivity in [0.0, 0.2, 0.5, 0.8]
    ls = jldopen("cart-pole-losses-sensitivity-$sensitivity.jld2", "r") do file
        file["losses"]
    end

    plot!(plt, first.(ls), label="training-$sensitivity")
    plot!(plt, last.(ls), label="validation-$sensitivity")
end
ylims!(plt, (0, ylims(plt)[2]))
plt
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9700)" points="
# 42.1066,375.813 580.315,375.813 580.315,11.811 42.1066,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="42" y="11" width="539" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   171.549,370.353 171.549,17.2711
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   307.804,370.353 307.804,17.2711
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   444.06,370.353 444.06,17.2711
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,375.813 572.242,375.813
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,268.016 572.242,268.016
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,160.219 572.242,160.219
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,52.4214 572.242,52.4214
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,375.813 42.1066,11.811
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   171.549,375.813 171.549,370.353
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   307.804,375.813 307.804,370.353
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   444.06,375.813 444.06,370.353
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,375.813 50.1797,375.813
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,268.016 50.1797,268.016
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,160.219 50.1797,160.219
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,52.4214 50.1797,52.4214
#   "/>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 171.549, 389.613)" x="171.549" y="389.613">20</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 307.804, 389.613)" x="307.804" y="389.613">40</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 444.06, 389.613)" x="444.06" y="389.613">60</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">80</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 380.313)" x="36.1066" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 272.516)" x="36.1066" y="272.516">500</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 164.719)" x="36.1066" y="164.719">1000</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 56.9214)" x="36.1066" y="56.9214">1500</text>
# </g>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,295.135 48.9193,299.293
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.9193,299.293 55.7321,303.812
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   55.7321,303.812 62.5448,308.102
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   62.5448,308.102 69.3576,312.337
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.3576,312.337 76.1704,299.59
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   76.1704,299.59 82.9831,300.564
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   82.9831,300.564 89.7959,301.102
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   89.7959,301.102 96.6087,301.657
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   96.6087,301.657 103.421,302.376
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   103.421,302.376 110.234,293.886
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   110.234,293.886 117.047,295.518
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   117.047,295.518 123.86,297.147
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   123.86,297.147 130.672,299.04
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   130.672,299.04 137.485,300.76
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.485,300.76 144.298,300.438
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   144.298,300.438 151.111,303.024
#   "/>
# <polyline clip-path="url(#clip9702)" sty

# %%
LearningMPC.randomize!(x0, xstar, 0.1, 1.0)
results = LCPSim.simulate(x0, 
    net_controller,
    robot.environment, mpc_params.Δt, 200, mpc_params.lcp_solver);

# %%
LearningMPC.playback(basevis[:robot], results, mpc_params.Δt)
